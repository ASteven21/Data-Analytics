# %% [markdown]
# # Movie Ratings EDA
#
# ## Questions to Answer
#
# - For each year and all time:
#     - Highest:
#         - imdb rating
#         - meta score
#         - number of votes
#         - runtime
#         - gross
#     - Lowest:
#         - imdb rating
#         - meta score
#         - number of votes
#         - runtime
#         - gross
#
# - Does the duration of movies in the 2000s last longer compared to the 1900s?
# - Does movies in the 1900s tend to have a higher rating than the 2000s?
# - Count of certificate category (ex: A 4, UA 8, etc)
# - Does a high gross movie mean a higher rating for a given movie?
# - Does a high no. of votes mean that a movie will have a higher gross?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

mv_rating = pd.read_csv('dataset/imdb_top_1000.csv')

mv_rating.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# ## Cleaning Data
#
# Before starting on doing some analysis, we have to clean the data first in order to minimize
# mistakes if it were to happen and also in order to ensure an accurate result.

# %%
# Checking the dtypes of each column and check for the number of non null values for each column

mv_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# #### Cleaning the 'Runtime' column
#
# We can see from the result above that the 'Runtime' column seem to have a object dtype / str dtype.
# We have to change this dtype from object to int.
# From the dataframe seen above, the 'Runtime' column has the word 'min' beside the minute number.
# In order to deal with this, we have to remove the word 'min' and convert the result into the dtype int.
#
# Steps to accomplish this:
#     1. Remove 'min'
#     2. convert dtype to int

# %%
# Making a new column where runtime is only a number and dropping columns that i'm not interested in
# Copied the original df to a new var so I don't change the original df if I mess up.

mv_rating_edit = mv_rating.copy()

# I used the insert method so that I can move the 'Runtime_min' column beside the 'Runtime' column

Runtime_min = mv_rating['Runtime'].str.replace('min', '')
mv_rating_edit.insert(mv_rating.columns.get_loc('Runtime'), 'Runtime_min', Runtime_min)
mv_rating_edit.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate Runtime_min  Runtime  \
# 0  The Shawshank Redemption          1994           A        142   142 min
# 1             The Godfather          1972           A        175   175 min
# 2           The Dark Knight          2008          UA        152   152 min
# 3    The Godfather: Part II          1974           A        202   202 min
# 4              12 Angry Men          1957           U         96    96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
# Change Runtime_num dtype to int

mv_rating_edit['Runtime_min'] = mv_rating_edit['Runtime_min'].astype(int)
mv_rating_edit['Runtime_min'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### Cleaning the 'Gross' column
#
# Here, I'm thinking of making a new column called 'Gross_num' where it will contain the value
# from the 'Gross' column but without the ',' and converting the dtype from object to int.
#
# I'll also deal with the NaN values and replace it with either the mean or median value.
# By looking at the difference between the mean and median value,
# we can see the whether or not outliers are present or not. If the difference is huge, I'll use the median value
# to replace the NaN values since it's not sensitive to outliers.
#
# Steps to accomplish this:
#     1. Remove ','
#     2. Filter for non null values
#     3. Take the mean and median to compare it
#     4. Replace NaNs with the selected parameter (mean or median)

# %%
# Convert the gross column from string to int and also remove the ',' delim

mv_rating_edit['Gross_num'] = mv_rating_edit['Gross'].str.replace(',', '')

# filtering for non null column and convert dtype to int

gross_num_nonull = mv_rating_edit[~mv_rating_edit['Gross_num'].isnull()].copy()
gross_num_nonull['Gross_num'] = gross_num_nonull['Gross_num'].astype(int)

# check the mean and median values for gross_num

mean_gross_num = gross_num_nonull['Gross_num'].mean()
median_gross_num = gross_num_nonull['Gross_num'].median()
print(f'mean gross: {mean_gross_num}\nmedian gross: {median_gross_num}')
# Out:
# mean gross: 68034750.87364621
# median gross: 23530892.0

# %%
# choose the median gross since it appears that outliers are present in the 'Gross_num' column
# we can see prove this by looking at the boxplot

plt.boxplot(gross_num_nonull['Gross_num'])
plt.ylabel('Gross in USD')
plt.grid()
plt.show()

# %%
# From the boxplot above, we can see that there are a lot of outliers which causes
# The mean to be very high. therefore, we should use the median since it's robust to outliers

# Replace the NaN values with the median and converting the dtype to int

mv_rating_edit['Gross_num'] = mv_rating_edit['Gross_num'].fillna(median_gross_num)
mv_rating_edit['Gross_num'] = mv_rating_edit['Gross_num'].astype(int)

mv_rating_edit.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime_min  Runtime  \
# 0  The Shawshank Redemption          1994           A          142  142 min
# 1             The Godfather          1972           A          175  175 min
# 2           The Dark Knight          2008          UA          152  152 min
# 3    The Godfather: Part II          1974           A          202  202 min
# 4              12 Angry Men          1957           U           96   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross  Gross_num
# 0  William Sadler      2343110   28,341,469   28341469
# 1    Diane Keaton      1620367  134,966,411  134966411
# 2   Michael Caine      2303232  534,858,444  534858444
# 3    Diane Keaton      1129952   57,300,000   57300000
# 4    John Fiedler       689845    4,360,000    4360000

# %%
# Check to see if we successfully filled in the NaN values and successfully changed the dtype

mv_rating_edit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime_min    1000 non-null   int64
#  5   Runtime        1000 non-null   object
#  6   Genre          1000 non-null   object
#  7   IMDB_Rating    1000 non-null   float64
#  8   Overview       1000 non-null   object
#  9   Meta_score     843 non-null    float64
#  10  Director       1000 non-null   object
#  11  Star1          1000 non-null   object
#  12  Star2          1000 non-null   object
#  13  Star3          1000 non-null   object
#  14  Star4          1000 non-null   object
#  15  No_of_Votes    1000 non-null   int64
#  16  Gross          831 non-null    object
#  17  Gross_num      1000 non-null   int64
# dtypes: float64(2), int64(3), object(13)
# memory usage: 140.8+ KB

# %% [markdown]
# #### Cleaning the 'Meta_score' column
#
# For this part, I'll do the exact same thing with the one I did for the 'Gross_num' column.
# I don't know if replacing the NaN values with the mean or median value is fair but so far this is
# what I can think of.
#
# Maybe by looking at the relationship between the meta score and imdb rating, we might be able
# to at least approximate what the value of the meta score for a given movie with an NaN value will be.
#
# Steps to accomplish this:
#     1. Filter for non NaN values
#     2. Take the mean or median
#     3. Replace the NaN values with the chosen parameter (mean or median)

# %%
# Try to see the relationship between metascore and rating to fill in NaN value in the metascore column

sns.stripplot(x='IMDB_Rating', y='Meta_score', data=mv_rating_edit, jitter=True, alpha=0.3)
plt.xlabel('imdb_rating')
plt.ylabel('meta score')
plt.show()

# %% [markdown]
# From the result of the scatter plot above, it seems like imdb rating is more of a categorical variable rather than a continous
# variable even after adding jitter. It doesn't tell us anything if a higher imdb rating would mean a higher meta score. This means that we would have to use either the mean or median to fill the NaN values of the meta score.

# %%
# Filter for non NaN values and check their mean and median values

metascore_nonull = mv_rating_edit[~mv_rating_edit['Meta_score'].isnull()]

mean_metascore = metascore_nonull['Meta_score'].mean()
median_metascore = metascore_nonull['Meta_score'].median()
print(f'mean meta score: {mean_metascore}\nmedian meta score: {median_metascore}')
# Out:
# mean meta score: 77.97153024911032
# median meta score: 79.0

# %%
# The 'Meta_score' column seem to be normally distributed. We can use the mean value here since there
# seem to be very little or no outliers.

# We can prove this by making a boxplot like we did with the 'Gross_num' column

plt.boxplot(metascore_nonull['Meta_score'])
plt.ylabel('Meta Score')
plt.grid()
plt.show()

# %%
# From the boxplot, we see that the outliers seem to be few in number.
# In this case, I'll use the mean to replace the NaN values

# Replace NaN with the mean value
mv_rating_edit['Meta_score'] = mv_rating_edit['Meta_score'].fillna(round(mean_metascore))

# Check whether it works or not by using the info method
mv_rating_edit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime_min    1000 non-null   int64
#  5   Runtime        1000 non-null   object
#  6   Genre          1000 non-null   object
#  7   IMDB_Rating    1000 non-null   float64
#  8   Overview       1000 non-null   object
#  9   Meta_score     1000 non-null   float64
#  10  Director       1000 non-null   object
#  11  Star1          1000 non-null   object
#  12  Star2          1000 non-null   object
#  13  Star3          1000 non-null   object
#  14  Star4          1000 non-null   object
#  15  No_of_Votes    1000 non-null   int64
#  16  Gross          831 non-null    object
#  17  Gross_num      1000 non-null   int64
# dtypes: float64(2), int64(3), object(13)
# memory usage: 140.8+ KB

# %% [markdown]
# #### Dropping columns
#
# Since there are columns that are not necessary for answering the questions that have already been presented above, we can just drop them.
#
# From the info table above, the 'Poster_Link' column and the 'Gross' column will not be necessary since we're not going to use the 'Poster_Link' column for the analysis as well as the 'Gross' column since we already have the 'Gross_num' column that was recently made previously.

# %%
# Dropping the 'Poster_Link' and 'Gross' columns

# Making a copy just in case if something goes wrong, we can still use the mv_rating_edit df
mv_rating_edit2 = mv_rating_edit.copy()

mv_rating_edit2 = mv_rating_edit2.drop(['Poster_Link', 'Gross'], axis=1)
mv_rating_edit2.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime_min  Runtime  \
# 0  The Shawshank Redemption          1994           A          142  142 min
# 1             The Godfather          1972           A          175  175 min
# 2           The Dark Knight          2008          UA          152  152 min
# 3    The Godfather: Part II          1974           A          202  202 min
# 4              12 Angry Men          1957           U           96   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes  Gross_num
# 0  William Sadler      2343110   28341469
# 1    Diane Keaton      1620367  134966411
# 2   Michael Caine      2303232  534858444
# 3    Diane Keaton      1129952   57300000
# 4    John Fiedler       689845    4360000

# %%
mv_rating_edit2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Certificate    899 non-null    object
#  3   Runtime_min    1000 non-null   int64
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     1000 non-null   float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross_num      1000 non-null   int64
# dtypes: float64(2), int64(3), object(11)
# memory usage: 125.1+ KB

# %% [markdown]
# #### Cleaning the 'Certificate' column
#
# As we can see from the info table above, the df is almost cleaned up. The last thing that needs to be done is to deal with the 'Certificate' column since there are NaN values.

# %%
# Checking the unqiue values of the 'Certificate' column

mv_rating_edit2['Certificate'].unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %% [markdown]
# Notes:<br>
# same meaning:
# - U = G
# - UA = U/A
# - PG = GP = TV-PG
# - A = TV-MA
# - Approved = Passed (assume that they mean the same thing)
#
# own thing:
# - TV-14
# - PG-13
# - 16
# - R
# - Unrated
# - Passed
#
# use df.map({})

# %%
# Since there seem to be movie certificates that comes from different countries, some category
# mean the same thing, so I tried to change them into one category if their meaning is the same

mapping = {'U':'U',
           'G':'U',
           'U/A':'UA',
           'UA':'UA',
           'GP':'PG',
           'PG':'PG',
           'TV-PG':'PG', 
           'TV-MA':'A',
           'A':'A',
           'Passed':'Approved',
           'Approved':'Approved',
           'TV-14':'TV-14',
           'PG-13':'PG-13',
           'R':'R',
           'Unrated':'Unrated',
           'Passed':'Passed',
           '16':'16'}


# Create a new column called 'Certificate_new' and fill it with the mapped values

Certificate_new = mv_rating_edit2['Certificate'].map(mapping)
mv_rating_edit2.insert(mv_rating_edit2.columns.get_loc('Certificate'), 'Certificate_new', Certificate_new)
mv_rating_edit2.head()
# Out:
#                Series_Title Released_Year Certificate_new Certificate  \
# 0  The Shawshank Redemption          1994               A           A
# 1             The Godfather          1972               A           A
# 2           The Dark Knight          2008              UA          UA
# 3    The Godfather: Part II          1974               A           A
# 4              12 Angry Men          1957               U           U
#
#    Runtime_min  Runtime                 Genre  IMDB_Rating  \
# 0          142  142 min                 Drama          9.3
# 1          175  175 min          Crime, Drama          9.2
# 2          152  152 min  Action, Crime, Drama          9.0
# 3          202  202 min          Crime, Drama          9.0
# 4           96   96 min          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes  Gross_num
# 0  William Sadler      2343110   28341469
# 1    Diane Keaton      1620367  134966411
# 2   Michael Caine      2303232  534858444
# 3    Diane Keaton      1129952   57300000
# 4    John Fiedler       689845    4360000

# %%
# Check to see if there are any patterns that causes a NaN value

colnames = mv_rating_edit2.columns

for colname in colnames:
    msno.matrix(mv_rating_edit2.sort_values(colname))
    plt.title('Ordered by ' + colname + ' (ascending)', fontsize=40)

# %% [markdown]
# From the figures above, we can see that the NaN values in the 'Certificate_new' column are spread out randomly but an interesting thing that we can observe is that in the 'Ordered by No_of_Votes (ascending)' figure, the NaN values seem to be clustered on top when compared with other figures. It seems like lower number of votes has something to do with the certification of a movie.
#
# Unfortunately, I can't think of any method in order to deal with this one so I'm thinking about setting the NaN values to 'unknown' however, by setting it to 'unknown' it still doesn't tell us anything when answering the questions that have been set above. Therefore, I think that I'll drop the NaN values since out of 1000 rows, there are only 111 missing observations (based on the info table). This means that there are still 899 observations (88.9% of the data) that we can use to analyze.

# %%
# Dropping NaN values from 'Certificate_new'

mv_rating_edit3 = mv_rating_edit2.dropna(axis=0).copy()
mv_rating_edit3.head()
# Out:
#                Series_Title Released_Year Certificate_new Certificate  \
# 0  The Shawshank Redemption          1994               A           A
# 1             The Godfather          1972               A           A
# 2           The Dark Knight          2008              UA          UA
# 3    The Godfather: Part II          1974               A           A
# 4              12 Angry Men          1957               U           U
#
#    Runtime_min  Runtime                 Genre  IMDB_Rating  \
# 0          142  142 min                 Drama          9.3
# 1          175  175 min          Crime, Drama          9.2
# 2          152  152 min  Action, Crime, Drama          9.0
# 3          202  202 min          Crime, Drama          9.0
# 4           96   96 min          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes  Gross_num
# 0  William Sadler      2343110   28341469
# 1    Diane Keaton      1620367  134966411
# 2   Michael Caine      2303232  534858444
# 3    Diane Keaton      1129952   57300000
# 4    John Fiedler       689845    4360000

# %%
mv_rating_edit3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 899 entries, 0 to 997
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Series_Title     899 non-null    object
#  1   Released_Year    899 non-null    object
#  2   Certificate_new  899 non-null    object
#  3   Certificate      899 non-null    object
#  4   Runtime_min      899 non-null    int64
#  5   Runtime          899 non-null    object
#  6   Genre            899 non-null    object
#  7   IMDB_Rating      899 non-null    float64
#  8   Overview         899 non-null    object
#  9   Meta_score       899 non-null    float64
#  10  Director         899 non-null    object
#  11  Star1            899 non-null    object
#  12  Star2            899 non-null    object
#  13  Star3            899 non-null    object
#  14  Star4            899 non-null    object
#  15  No_of_Votes      899 non-null    int64
#  16  Gross_num        899 non-null    int64
# dtypes: float64(2), int64(3), object(12)
# memory usage: 126.4+ KB

# %% [markdown]
# #### Cleaning the 'Released_Year' column
#
# For this part, I'll change the dtype from object to int. <br>
# I'm not changing it to the datetime dtype because I only need the year.

# %%
# Look at the unique values

mv_rating_edit3['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1954',
#        '1946', '2011', '2006', '2000', '1988', '1985', '1968', '1960',
#        '1942', '1936', '1931', '2018', '2017', '2016', '2012', '2009',
#        '2007', '1984', '1981', '1979', '1971', '1964', '1950', '1940',
#        '2013', '2004', '1992', '1987', '1986', '1983', '1976', '1973',
#        '1965', '1962', '1959', '1958', '1952', '1944', '1941', '1921',
#        '2015', '2005', '1989', '1978', '1963', '1961', '1953', '1948',
#        '1925', '1924', '1996', '1982', '1967', '1951', '1949', '1939',
#        '1934', '1928', '1927', '1926', '1970', '1969', '1956', '1945',
#        '1930', '1955', '1938', '1935', '1933', '1943', '1932', 'PG'],
#       dtype=object)

# %% [markdown]
# There seem to be an error when inputing the 'Released_Year' column. From the array above, 'PG' can be seen at the last index of the array. Fortunately there's only one error which means that I can just find out what the movie title is and search in the internet about the release year and change it manually.

# %%
# Finding out the movie with a release year of 'PG'

mv_rating_edit3[mv_rating_edit3['Released_Year'] == 'PG']
# Out:
#     Series_Title Released_Year Certificate_new Certificate  Runtime_min  \
# 966    Apollo 13            PG               U           U          140
#
#      Runtime                      Genre  IMDB_Rating  \
# 966  140 min  Adventure, Drama, History          7.6
#
#                                               Overview  Meta_score  \
# 966  NASA must devise a strategy to return Apollo 1...        77.0
#
#        Director      Star1        Star2        Star3        Star4  \
# 966  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes  Gross_num
# 966       269197  173837933

# %% [markdown]
# It looks like Apollo 13 is the one that has a release year of 'PG'. <br>
# After searching on the imdb website, it appears that the release year of Apollo 13 was in the year 1995. <br><br>
# The screenshot can be seen below:
#
# ![apollo13.png](attachment:apollo13.png)

# %%
# Set the release year for Apollo 13  to 1995
# From the df above, the index of Apollo 13 is 966

mv_rating_edit3.loc[966, 'Released_Year'] = 1995
mv_rating_edit3[mv_rating_edit3['Series_Title'] == 'Apollo 13']
# Out:
#     Series_Title Released_Year Certificate_new Certificate  Runtime_min  \
# 966    Apollo 13          1995               U           U          140
#
#      Runtime                      Genre  IMDB_Rating  \
# 966  140 min  Adventure, Drama, History          7.6
#
#                                               Overview  Meta_score  \
# 966  NASA must devise a strategy to return Apollo 1...        77.0
#
#        Director      Star1        Star2        Star3        Star4  \
# 966  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes  Gross_num
# 966       269197  173837933

# %%
# After successfully changing the release year, I'll change the dtype to int
mv_rating_edit3['Released_Year'] = mv_rating_edit3['Released_Year'].astype(int)

mv_rating_edit3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 899 entries, 0 to 997
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Series_Title     899 non-null    object
#  1   Released_Year    899 non-null    int64
#  2   Certificate_new  899 non-null    object
#  3   Certificate      899 non-null    object
#  4   Runtime_min      899 non-null    int64
#  5   Runtime          899 non-null    object
#  6   Genre            899 non-null    object
#  7   IMDB_Rating      899 non-null    float64
#  8   Overview         899 non-null    object
#  9   Meta_score       899 non-null    float64
#  10  Director         899 non-null    object
#  11  Star1            899 non-null    object
#  12  Star2            899 non-null    object
#  13  Star3            899 non-null    object
#  14  Star4            899 non-null    object
#  15  No_of_Votes      899 non-null    int64
#  16  Gross_num        899 non-null    int64
# dtypes: float64(2), int64(4), object(11)
# memory usage: 158.7+ KB

# %% [markdown]
# #### Final dropping of columns
#
# For the final part before the cleaning, I'll drop the 'Certificate', 'Runtime' columns because I already have the 'Certificate_new' and 'Runtime_min' columns

# %%
mv_rating_clean = mv_rating_edit3.copy()
mv_rating_clean = mv_rating_edit3.drop(['Certificate', 'Runtime'], axis=1)
mv_rating_clean.head()
# Out:
#                Series_Title  Released_Year Certificate_new  Runtime_min  \
# 0  The Shawshank Redemption           1994               A          142
# 1             The Godfather           1972               A          175
# 2           The Dark Knight           2008              UA          152
# 3    The Godfather: Part II           1974               A          202
# 4              12 Angry Men           1957               U           96
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes  Gross_num
# 0  William Sadler      2343110   28341469
# 1    Diane Keaton      1620367  134966411
# 2   Michael Caine      2303232  534858444
# 3    Diane Keaton      1129952   57300000
# 4    John Fiedler       689845    4360000

# %% [markdown]
# ## Analysis
#
# Now that the df is already clean, I can start answering the questions that were established previously.
#
# I'll start with finding out movies with the highest and lowest imdb rating for each year and all time.
#
#
# #### Highest IMDB Rating
# In this part, I'll find the movie with the highest all time rating and also the highest movie rating grouped by year.

# %%
# Highest imdb rated movie (all time)

at_high_rating = mv_rating_clean[mv_rating_clean['IMDB_Rating'] == mv_rating_clean['IMDB_Rating'].max()]
at_high_rating[['Released_Year', 'IMDB_Rating', 'Series_Title']].set_index('Released_Year')
# Out:
#                IMDB_Rating              Series_Title
# Released_Year
# 1994                   9.3  The Shawshank Redemption

# %%
# Highest imdb rated movie grouped by release year

high_rating_by_year = mv_rating_clean.groupby('Released_Year')['IMDB_Rating'].max()
high_rating_by_year = high_rating_by_year.sort_index().reset_index()
print(high_rating_by_year.to_string()) # to_string() used to display all the result
# Out:
#     Released_Year  IMDB_Rating
# 0            1921          8.3
# 1            1924          8.2
# 2            1925          8.2
# 3            1926          8.1
# 4            1927          8.1
# 5            1928          8.1
# 6            1930          8.0
# 7            1931          8.5
# 8            1932          7.8
# 9            1933          7.9
# 10           1934          8.1
# 11           1935          7.9
# 12           1936          8.5
# 13           1938          7.9
# 14           1939          8.1
# 15           1940          8.4
# 16           1941          8.3
# 17           1942          8.5
# 18           1943          7.8
# 19           1944          8.3
# 20           1945          8.0
# 21           1946          8.6
# 22           1948          8.2
# 23           1949          8.1
# 24           1950          8.4
# 25           1951          8.1
# 26           1952          8.3
# 27           1953          8.2
# 28           1954          8.6
# 29           1955          7.9
# 30           1956          8.0
# 31           1957          9.0
# 32           1958          8.3
# 33           1959          8.3
# 34           1960          8.5
# 35           1961          8.2
# 36           1962          8.3
# 37           1963          8.2
# 38           1964          8.4
# 39           1965          8.3
# 40           1966          8.8
# 41           1967          8.1
# 42           1968          8.5
# 43           1969          8.0
# 44           1970          8.0
# 45           1971          8.4
# 46           1972          9.2
# 47           1973          8.3
# 48           1974          9.0
# 49           1975          8.7
# 50           1976          8.3
# 51           1977          8.6
# 52           1978          8.2
# 53           1979          8.4
# 54           1980          8.7
# 55           1981          8.4
# 56           1982          8.1
# 57           1983          8.3
# 58           1984          8.4
# 59           1985          8.5
# 60           1986          8.3
# 61           1987          8.3
# 62           1988          8.5
# 63           1989          8.2
# 64           1990          8.7
# 65           1991          8.6
# 66           1992          8.3
# 67           1993          8.9
# 68           1994          9.3
# 69           1995          8.6
# 70           1996          8.1
# 71           1997          8.6
# 72           1998          8.6
# 73           1999          8.8
# 74           2000          8.5
# 75           2001          8.8
# 76           2002          8.7
# 77           2003          8.9
# 78           2004          8.3
# 79           2005          8.2
# 80           2006          8.5
# 81           2007          8.4
# 82           2008          9.0
# 83           2009          8.4
# 84           2010          8.8
# 85           2011          8.5
# 86           2012          8.4
# 87           2013          8.3
# 88           2014          8.6
# 89           2015          8.2
# 90           2016          8.4
# 91           2017          8.4
# 92           2018          8.4
# 93           2019          8.6
# 94           2020          8.6

# %% [markdown]
# The result above only shows the highest rating given to a particular movie in each year. If the title of the movie is to be shown, it only shows one movie with that particular rating.
#
# ex: In the year 1924, the highest rating given to a particular movie is 8.2. If for example there are 2 movies with a rating of 8.2, it will only display the first movie that it encounters first.
#
# Since I want to include every movie with the same rating, The result above will not suffice. The only way that I could think of solving this is by iterating using a for loop and put the result in a new dataframe shown on the code below.

# %%
# Putting all the values into a list
high_ratings = high_rating_by_year['IMDB_Rating'].tolist()
release_years = high_rating_by_year['Released_Year'].tolist()

# Empty list for appending the result of the for loop
movie_list = []

for rating, year in zip(high_ratings, release_years):
    res = mv_rating_clean[(mv_rating_clean['Released_Year'] == year) & (mv_rating_clean['IMDB_Rating'] == rating)]
    movie_list.append(res)

# Concatenating the values in the list into a dataframe
high_rated_movies_by_year = pd.concat(movie_list) 
high_rated_movies_by_year = high_rated_movies_by_year[['Released_Year', 'IMDB_Rating', 'Series_Title']].set_index('Released_Year')
print(high_rated_movies_by_year.to_string())
# Out:
#                IMDB_Rating                                                          Series_Title
# Released_Year
# 1921                   8.3                                                               The Kid
# 1924                   8.2                                                          Sherlock Jr.
# 1925                   8.2                                                         The Gold Rush
# 1926                   8.1                                                           The General
# 1927                   8.1                                         Sunrise: A Song of Two Humans
# 1928                   8.1                                            La passion de Jeanne d'Arc
# 1928                   8.1                                                            The Circus
# 1930                   8.0                                        All Quiet on the Western Front
# 1931                   8.5                                                           City Lights
# 1932                   7.8                                     Scarface: The Shame of the Nation
# 1933                   7.9                                                             King Kong
# 1934                   8.1                                                 It Happened One Night
# 1935                   7.9                                                  A Night at the Opera
# 1936                   8.5                                                          Modern Times
# 1938                   7.9                                          The Adventures of Robin Hood
# 1939                   8.1                                          Mr. Smith Goes to Washington
# 1939                   8.1                                                    Gone with the Wind
# 1940                   8.4                                                    The Great Dictator
# 1941                   8.3                                                          Citizen Kane
# 1942                   8.5                                                            Casablanca
# 1943                   7.8                                                     Shadow of a Doubt
# 1944                   8.3                                                      Double Indemnity
# 1945                   8.0                                                       Brief Encounter
# 1946                   8.6                                                 It's a Wonderful Life
# 1948                   8.2                                      The Treasure of the Sierra Madre
# 1949                   8.1                                                         The Third Man
# 1950                   8.4                                                          Sunset Blvd.
# 1951                   8.1                                                       Ace in the Hole
# 1952                   8.3                                                   Singin' in the Rain
# 1953                   8.2                                                      Tôkyô monogatari
# 1954                   8.6                                                  Shichinin no samurai
# 1955                   7.9                                                          East of Eden
# 1956                   8.0                                                           The Killing
# 1957                   9.0                                                          12 Angry Men
# 1958                   8.3                                                               Vertigo
# 1959                   8.3                                                    North by Northwest
# 1960                   8.5                                                                Psycho
# 1961                   8.2                                                 Judgment at Nuremberg
# 1962                   8.3                                                    Lawrence of Arabia
# 1963                   8.2                                                      The Great Escape
# 1964                   8.4  Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 1965                   8.3                                            Per qualche dollaro in più
# 1966                   8.8                                       Il buono, il brutto, il cattivo
# 1967                   8.1                                                           Le samouraï
# 1967                   8.1                                                        Cool Hand Luke
# 1968                   8.5                                          Once Upon a Time in the West
# 1969                   8.0                                    Butch Cassidy and the Sundance Kid
# 1970                   8.0                                                        Il conformista
# 1971                   8.4                                                                 Anand
# 1972                   9.2                                                         The Godfather
# 1973                   8.3                                                             The Sting
# 1974                   9.0                                                The Godfather: Part II
# 1975                   8.7                                       One Flew Over the Cuckoo's Nest
# 1976                   8.3                                                           Taxi Driver
# 1977                   8.6                                                             Star Wars
# 1978                   8.2                                                           Höstsonaten
# 1979                   8.4                                                        Apocalypse Now
# 1979                   8.4                                                                 Alien
# 1980                   8.7                        Star Wars: Episode V - The Empire Strikes Back
# 1981                   8.4                                               Raiders of the Lost Ark
# 1982                   8.1                                                             The Thing
# 1982                   8.1                                                  Pink Floyd: The Wall
# 1982                   8.1                                                          Fitzcarraldo
# 1982                   8.1                                                   Fanny och Alexander
# 1982                   8.1                                                          Blade Runner
# 1983                   8.3                                                              Scarface
# 1983                   8.3                            Star Wars: Episode VI - Return of the Jedi
# 1984                   8.4                                           Once Upon a Time in America
# 1985                   8.5                                                    Back to the Future
# 1986                   8.3                                                                Aliens
# 1987                   8.3                                                     Full Metal Jacket
# 1988                   8.5                                                 Nuovo Cinema Paradiso
# 1988                   8.5                                                        Hotaru no haka
# 1989                   8.2                                    Indiana Jones and the Last Crusade
# 1990                   8.7                                                            Goodfellas
# 1991                   8.6                                              The Silence of the Lambs
# 1992                   8.3                                                        Reservoir Dogs
# 1993                   8.9                                                      Schindler's List
# 1994                   9.3                                              The Shawshank Redemption
# 1995                   8.6                                                                 Se7en
# 1996                   8.1                                                         Trainspotting
# 1996                   8.1                                                                 Fargo
# 1997                   8.6                                                       La vita è bella
# 1998                   8.6                                                   Saving Private Ryan
# 1999                   8.8                                                            Fight Club
# 2000                   8.5                                                             Gladiator
# 2001                   8.8                     The Lord of the Rings: The Fellowship of the Ring
# 2002                   8.7                                 The Lord of the Rings: The Two Towers
# 2003                   8.9                         The Lord of the Rings: The Return of the King
# 2004                   8.3                                 Eternal Sunshine of the Spotless Mind
# 2005                   8.2                                                        V for Vendetta
# 2005                   8.2                                                                 Black
# 2005                   8.2                                                         Batman Begins
# 2006                   8.5                                                          The Prestige
# 2006                   8.5                                                          The Departed
# 2007                   8.4                                                      Taare Zameen Par
# 2008                   9.0                                                       The Dark Knight
# 2009                   8.4                                                              3 Idiots
# 2010                   8.8                                                             Inception
# 2011                   8.5                                                      The Intouchables
# 2012                   8.4                                                      Django Unchained
# 2012                   8.4                                                 The Dark Knight Rises
# 2013                   8.3                                                              Drishyam
# 2014                   8.6                                                          Interstellar
# 2015                   8.2                                                                Talvar
# 2015                   8.2                                                              Drishyam
# 2016                   8.4                                                        Kimi no na wa.
# 2016                   8.4                                                                Dangal
# 2017                   8.4                                                          Vikram Vedha
# 2017                   8.4                                                                  Coco
# 2018                   8.4                                                            Capharnaüm
# 2018                   8.4                                     Spider-Man: Into the Spider-Verse
# 2018                   8.4                                                Avengers: Infinity War
# 2019                   8.6                                                          Gisaengchung
# 2020                   8.6                                                              Hamilton
# 2020                   8.6                                                       Soorarai Pottru

# %% [markdown]
# As seen on the results shown above, I've managed to find the name of movies which has the highest rating for a given year. Unlike the previous code which only gives one movie title with the highest rating in each year, this code gives all of the movies which has the highest rating for each year.
#
#
# While looking at the code before the one above, I suddenly got curious about the trend of the highest rated movies over time, so I decided to do a small side quest by plotting a line plot as seen below.

# %%
# Plot a graph to show the trend of highest movie rating over time

plt.plot(high_rated_movies_by_year.index, high_rated_movies_by_year.IMDB_Rating, marker='.')
plt.xlabel('Year')
plt.ylabel('IMDB Rating')
plt.title('Highest IMDB Rating Over Time')
plt.grid()
plt.show()

# %% [markdown]
# From the graph above, the graph shows fluctuations of the highest rated movies over time from the year 1920 to 2020. However, the overall trend of this graph is going up or in other words, the highest rating keeps on increasing as time goes by.
#
# While this is an interesting information to have, in my opinion, it doesn't tell the overall story about how movies are doing for a given year. I personally think that taking the median of the ratings will help in giving a bigger picture of how these movies are doing.
#
# I decided to take the median here since it's more robust to outliers in case if outliers are present.

# %%
# Taking the median 

mid_movie_rating_by_year = mv_rating_clean.groupby('Released_Year')['IMDB_Rating'].median().reset_index()
print(mid_movie_rating_by_year.to_string())
# Out:
#     Released_Year  IMDB_Rating
# 0            1921         8.30
# 1            1924         8.20
# 2            1925         8.20
# 3            1926         8.10
# 4            1927         8.10
# 5            1928         8.10
# 6            1930         8.00
# 7            1931         8.30
# 8            1932         7.80
# 9            1933         7.80
# 10           1934         8.05
# 11           1935         7.90
# 12           1936         8.50
# 13           1938         7.85
# 14           1939         8.05
# 15           1940         8.00
# 16           1941         8.30
# 17           1942         8.35
# 18           1943         7.80
# 19           1944         8.00
# 20           1945         7.95
# 21           1946         7.90
# 22           1948         8.00
# 23           1949         8.05
# 24           1950         8.20
# 25           1951         7.90
# 26           1952         7.90
# 27           1953         8.10
# 28           1954         8.20
# 29           1955         7.80
# 30           1956         7.90
# 31           1957         8.20
# 32           1958         8.00
# 33           1959         8.15
# 34           1960         8.00
# 35           1961         7.90
# 36           1962         8.10
# 37           1963         7.90
# 38           1964         7.80
# 39           1965         8.00
# 40           1966         8.00
# 41           1967         7.90
# 42           1968         8.00
# 43           1969         7.90
# 44           1970         7.90
# 45           1971         7.90
# 46           1972         8.00
# 47           1973         7.85
# 48           1974         7.90
# 49           1975         8.10
# 50           1976         8.10
# 51           1977         8.00
# 52           1978         7.80
# 53           1979         7.90
# 54           1980         8.05
# 55           1981         7.95
# 56           1982         8.00
# 57           1983         7.90
# 58           1984         8.00
# 59           1985         7.80
# 60           1986         7.90
# 61           1987         7.80
# 62           1988         8.10
# 63           1989         7.80
# 64           1990         7.80
# 65           1991         7.80
# 66           1992         7.70
# 67           1993         7.85
# 68           1994         8.10
# 69           1995         8.00
# 70           1996         7.80
# 71           1997         7.80
# 72           1998         8.00
# 73           1999         7.90
# 74           2000         7.90
# 75           2001         7.80
# 76           2002         7.80
# 77           2003         8.00
# 78           2004         7.90
# 79           2005         7.80
# 80           2006         7.85
# 81           2007         7.80
# 82           2008         7.90
# 83           2009         7.80
# 84           2010         7.80
# 85           2011         7.80
# 86           2012         7.95
# 87           2013         7.85
# 88           2014         7.90
# 89           2015         7.90
# 90           2016         7.90
# 91           2017         7.80
# 92           2018         8.00
# 93           2019         7.90
# 94           2020         8.10

# %%
# Plotting the median of the ratings over time

plt.plot(mid_movie_rating_by_year.Released_Year, mid_movie_rating_by_year.IMDB_Rating, marker='.')
plt.xlabel('Year')
plt.ylabel('IMDB Rating')
plt.title('Median IMDB Rating Over Time')
plt.grid()
plt.show()

# %% [markdown]
# In contrast with the previous graph, it seems like the overall trend is going down or in other words, the average rating of movies tend to have a lower rating than the previous year.

# %% [markdown]
# #### Highest Meta Score
#
# In this part, I'll answer the second bullet point about movies with the highest all time meta score and movies with the highest meta score grouped by year.

# %%
# Movie with the highest all time meta score

at_high_ms = mv_rating_clean[mv_rating_clean['Meta_score'] == mv_rating_clean['Meta_score'].max()]
at_high_ms = at_high_ms[['Released_Year', 'Meta_score', 'Series_Title']].set_index('Released_Year').sort_index()
at_high_ms
# Out:
#                Meta_score            Series_Title
# Released_Year
# 1941                100.0            Citizen Kane
# 1942                100.0              Casablanca
# 1946                100.0               Notorious
# 1954                100.0             Rear Window
# 1957                100.0  Sweet Smell of Success
# 1958                100.0                 Vertigo
# 1962                100.0      Lawrence of Arabia
# 1970                100.0          Il conformista
# 1972                100.0           The Godfather
# 1982                100.0     Fanny och Alexander
# 1994                100.0   Trois couleurs: Rouge
# 2014                100.0                 Boyhood

# %%
f'No. of movies: {len(at_high_ms)}'
# Out:
# 'No. of movies: 12'

# %% [markdown]
# There appears to be 12 movies with a meta score of 100 ranging from 1941 to 2014. This is actually pretty interesting to me since I didn't expect any movie to have a meta score of 100 and it also surprises me to see 12 movies that has a meta score of 100.
#
# Now I'm going to find out movies with the highest meta score per year.

# %%
# Highest meta score grouped by year

high_ms_by_year = mv_rating_clean.groupby('Released_Year')['Meta_score'].max()
high_ms_by_year = high_ms_by_year.sort_index().reset_index()
print(high_ms_by_year.to_string())
# Out:
#     Released_Year  Meta_score
# 0            1921        78.0
# 1            1924        78.0
# 2            1925        78.0
# 3            1926        78.0
# 4            1927        78.0
# 5            1928        90.0
# 6            1930        91.0
# 7            1931        99.0
# 8            1932        87.0
# 9            1933        90.0
# 10           1934        87.0
# 11           1935        78.0
# 12           1936        96.0
# 13           1938        97.0
# 14           1939        97.0
# 15           1940        96.0
# 16           1941       100.0
# 17           1942       100.0
# 18           1943        94.0
# 19           1944        95.0
# 20           1945        92.0
# 21           1946       100.0
# 22           1948        98.0
# 23           1949        97.0
# 24           1950        98.0
# 25           1951        97.0
# 26           1952        99.0
# 27           1953        85.0
# 28           1954       100.0
# 29           1955        89.0
# 30           1956        94.0
# 31           1957       100.0
# 32           1958       100.0
# 33           1959        98.0
# 34           1960        97.0
# 35           1961        90.0
# 36           1962       100.0
# 37           1963        90.0
# 38           1964        97.0
# 39           1965        74.0
# 40           1966        90.0
# 41           1967        92.0
# 42           1968        96.0
# 43           1969        97.0
# 44           1970       100.0
# 45           1971        94.0
# 46           1972       100.0
# 47           1973        93.0
# 48           1974        92.0
# 49           1975        91.0
# 50           1976        94.0
# 51           1977        92.0
# 52           1978        93.0
# 53           1979        94.0
# 54           1980        89.0
# 55           1981        86.0
# 56           1982       100.0
# 57           1983        91.0
# 58           1984        92.0
# 59           1985        96.0
# 60           1986        92.0
# 61           1987        88.0
# 62           1988        94.0
# 63           1989        97.0
# 64           1990        90.0
# 65           1991        95.0
# 66           1992        86.0
# 67           1993        94.0
# 68           1994       100.0
# 69           1995        95.0
# 70           1996        91.0
# 71           1997        90.0
# 72           1998        91.0
# 73           1999        90.0
# 74           2000        94.0
# 75           2001        96.0
# 76           2002        87.0
# 77           2003        94.0
# 78           2004        90.0
# 79           2005        87.0
# 80           2006        98.0
# 81           2007        96.0
# 82           2008        95.0
# 83           2009        90.0
# 84           2010        95.0
# 85           2011        95.0
# 86           2012        94.0
# 87           2013        96.0
# 88           2014       100.0
# 89           2015        94.0
# 90           2016        96.0
# 91           2017        94.0
# 92           2018        96.0
# 93           2019        96.0
# 94           2020        90.0

# %%
# Same as before, I'll make a line graph to see the visualization of the data above.

plt.plot(high_ms_by_year['Released_Year'], high_ms_by_year['Meta_score'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Meta Score')
plt.title('Highest Meta Score Over Time')
plt.grid()
plt.show()

# %% [markdown]
# I find this graph to be very interesting because when looking at the overall trend, the graph is fluctuating all throughout the year that the trend looks stagnant. I can't really tell if the trend is going up or going down. From 1920 to 1940, an upward trend can be observed before the meta score falls to the exact point where it started from in the late 1930s before going up again. From there the trend fluctuates that it looks like the trend is stagnant except for the outlier in the mid 1960s.
#
# Before moving on to the finding the movie names, I'm curious about the meta score of the outlier. So before moving on, I'll find out the meta score of the outlier first.

# %%
# Finding out the outlier's movie title

high_out_ms_by_year = mv_rating_clean.groupby('Released_Year')['Meta_score'].max().reset_index()
high_out_ms_by_year[high_out_ms_by_year['Meta_score'] == high_out_ms_by_year['Meta_score'].min()]
# Out:
#     Released_Year  Meta_score
# 39           1965        74.0

# %% [markdown]
# It seems like the meta score of the outlier is 74. Now I'm going to find out the name of the movies with the highest meta score in each year and find out the movie name with the meta score of 74. But before that I'll plot a graph about the meta score median of each year.

# %%
# Plotting median graph
median_ms = mv_rating_clean.groupby('Released_Year')['Meta_score'].median().reset_index()
median_ms

plt.plot(median_ms.Released_Year, median_ms.Meta_score, marker='.')
plt.xlabel('Release Year')
plt.ylabel('Meta Score')
plt.title('Median Meta Score Over Time')
plt.grid()
plt.show()

# %% [markdown]
# From the graph above, the trend is clearly going down as time goes by. If we relate this with the median of the imdb rating, they seem to share the same trend. I'll further investigate this by making a scatter plot to see if they are correlated or not.
#
# This is actually out of the scope of the questions presented previously, but I think that it will be interesting to check this out.

# %%
# scatter plot of meta score vs imdb rating median values

new_df = pd.DataFrame(columns=['IMDB_Rating', 'Meta_score'])
new_df['IMDB_Rating'] = round(mid_movie_rating_by_year.IMDB_Rating, 1)
new_df['Meta_score'] = median_ms.Meta_score


sns.stripplot(x='IMDB_Rating', y='Meta_score', data=new_df, jitter=True, alpha=0.2, size=10, color='black')
plt.xlabel('IMDB Rating')
plt.ylabel('Meta Score')
plt.title('Median Meta Score vs IMDB Rating')
plt.show()

# %%
# Correlation coefficient of meta score and imdb rating

new_df.corr()
# Out:
#              IMDB_Rating  Meta_score
# IMDB_Rating     1.000000    0.346163
# Meta_score      0.346163    1.000000

# %% [markdown]
# At first glance, it looks like meta score and imdb rating are correlated in some way. After finding out the correlation coefficient however, the correlation between both of them is very weak which means that as imdb rating increases, it is not guaranteed that the meta score will increase also.

# %%
# Finding the movie names with the highest meta score in each year

ms_list = high_ms_by_year['Meta_score'].tolist()
year_list = high_ms_by_year['Released_Year'].tolist()

moviename_ms_list = []

for ms, year in zip(ms_list, year_list):
    res = mv_rating_clean[(mv_rating_clean['Released_Year'] == year) & (mv_rating_clean['Meta_score'] == ms)]
    moviename_ms_list.append(res)
    
final_ms_df = pd.concat(moviename_ms_list).set_index('Released_Year')
final_ms_df = final_ms_df[['Meta_score', 'Series_Title']]
print(final_ms_df.to_string())
# Out:
#                Meta_score                                                          Series_Title
# Released_Year
# 1921                 78.0                                                               The Kid
# 1924                 78.0                                                          Sherlock Jr.
# 1925                 78.0                                                         The Gold Rush
# 1926                 78.0                                                           The General
# 1927                 78.0                                         Sunrise: A Song of Two Humans
# 1928                 90.0                                                            The Circus
# 1930                 91.0                                        All Quiet on the Western Front
# 1931                 99.0                                                           City Lights
# 1932                 87.0                                     Scarface: The Shame of the Nation
# 1933                 90.0                                                             King Kong
# 1934                 87.0                                                 It Happened One Night
# 1935                 78.0                                                  A Night at the Opera
# 1936                 96.0                                                          Modern Times
# 1938                 97.0                                          The Adventures of Robin Hood
# 1939                 97.0                                                    Gone with the Wind
# 1940                 96.0                                                   The Grapes of Wrath
# 1940                 96.0                                                              Fantasia
# 1941                100.0                                                          Citizen Kane
# 1942                100.0                                                            Casablanca
# 1943                 94.0                                                     Shadow of a Doubt
# 1944                 95.0                                                      Double Indemnity
# 1945                 92.0                                                       Brief Encounter
# 1946                100.0                                                             Notorious
# 1948                 98.0                                      The Treasure of the Sierra Madre
# 1949                 97.0                                                         The Third Man
# 1950                 98.0                                                         All About Eve
# 1951                 97.0                                              A Streetcar Named Desire
# 1952                 99.0                                                   Singin' in the Rain
# 1953                 85.0                                                 Le salaire de la peur
# 1953                 85.0                                                 From Here to Eternity
# 1954                100.0                                                           Rear Window
# 1955                 89.0                                                 Rebel Without a Cause
# 1956                 94.0                                                         The Searchers
# 1957                100.0                                                Sweet Smell of Success
# 1958                100.0                                                               Vertigo
# 1959                 98.0                                                    North by Northwest
# 1959                 98.0                                                      Some Like It Hot
# 1960                 97.0                                                                Psycho
# 1961                 90.0                                                           The Hustler
# 1962                100.0                                                    Lawrence of Arabia
# 1963                 90.0                                                             The Birds
# 1964                 97.0  Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 1965                 74.0                                            Per qualche dollaro in più
# 1966                 90.0                                       Il buono, il brutto, il cattivo
# 1967                 92.0                                                        Cool Hand Luke
# 1968                 96.0                                                       Rosemary's Baby
# 1969                 97.0                                                        The Wild Bunch
# 1970                100.0                                                        Il conformista
# 1971                 94.0                                                 The French Connection
# 1972                100.0                                                         The Godfather
# 1973                 93.0                                                              Badlands
# 1974                 92.0                                                             Chinatown
# 1975                 91.0                                       Monty Python and the Holy Grail
# 1975                 91.0                                             The Man Who Would Be King
# 1976                 94.0                                                           Taxi Driver
# 1977                 92.0                                                            Annie Hall
# 1978                 93.0                                                        Days of Heaven
# 1979                 94.0                                                        Apocalypse Now
# 1980                 89.0                                                           Raging Bull
# 1981                 86.0                                                              Das Boot
# 1982                100.0                                                   Fanny och Alexander
# 1983                 91.0                                                       The Right Stuff
# 1984                 92.0                                                    This Is Spinal Tap
# 1985                 96.0                                                                   Ran
# 1986                 92.0                                                               Platoon
# 1987                 88.0                                                 Au revoir les enfants
# 1988                 94.0                                                        Hotaru no haka
# 1989                 97.0                              My Left Foot: The Story of Christy Brown
# 1990                 90.0                                                            Goodfellas
# 1991                 95.0                                                  Beauty and the Beast
# 1992                 86.0                                                               Aladdin
# 1993                 94.0                                                      Schindler's List
# 1994                100.0                                                 Trois couleurs: Rouge
# 1995                 95.0                                                             Toy Story
# 1996                 91.0                                                        Secrets & Lies
# 1997                 90.0                                                     L.A. Confidential
# 1998                 91.0                                                   Saving Private Ryan
# 1999                 90.0                                                  Being John Malkovich
# 2000                 94.0                                                       Wo hu cang long
# 2001                 96.0                                         Sen to Chihiro no kamikakushi
# 2002                 87.0                                 The Lord of the Rings: The Two Towers
# 2003                 94.0                         The Lord of the Rings: The Return of the King
# 2004                 90.0                                                         Before Sunset
# 2004                 90.0                                                       The Incredibles
# 2005                 87.0                                                    Brokeback Mountain
# 2006                 98.0                                                       Pan's Labyrinth
# 2007                 96.0                                                           Ratatouille
# 2008                 95.0                                                                WALL·E
# 2009                 90.0                                                           Un prophète
# 2010                 95.0                                                    The Social Network
# 2011                 95.0                                               Jodaeiye Nader az Simin
# 2012                 94.0                                                                 Amour
# 2013                 96.0                                                      12 Years a Slave
# 2013                 96.0                                                               Gravity
# 2014                100.0                                                               Boyhood
# 2015                 94.0                                                            Inside Out
# 2016                 96.0                                                 Manchester by the Sea
# 2017                 94.0                                                               Dunkirk
# 2018                 96.0                                                                  Roma
# 2019                 96.0                                                          Gisaengchung
# 2020                 90.0                                                              Hamilton

# %%
# Finding out the movie with a meta score of 74 (lowest among the rest)

final_ms_df[final_ms_df['Meta_score'] == 74.0]
# Out:
#                Meta_score                Series_Title
# Released_Year
# 1965                 74.0  Per qualche dollaro in più

# %% [markdown]
# It appears that 'Per qualche dollaro in più' has the lowest meta score among the other movies.

# %% [markdown]
# Note: I just realized that I'll be writing the same code over and over again. So starting from now, I'll make a function to find movie names to avoid writing the same code over and over again.

# %%
# Function for finding movie name

def movie_finder(Series_year, Series_var, year_title, var_title):
    year_list = Series_year.tolist()
    var_list = Series_var.tolist()
    
    result_list = []
    
    for year, var in zip(year_list, var_list):
        res = mv_rating_clean[(mv_rating_clean[year_title] == year) & (mv_rating_clean[var_title] == var)]
        result_list.append(res)
        
    final_df = pd.concat(result_list)
    return final_df

# %% [markdown]
# #### Highest No. of Votes
#
# Now I'm going to start answering the question about movies with the highest all time votes and also movies with the highest votes for each year.

# %%
# Movie with the highest all time votes

at_high_vote = mv_rating_clean[mv_rating_clean['No_of_Votes'] == mv_rating_clean['No_of_Votes'].max()]
at_high_vote[['Series_Title', 'No_of_Votes']]
# Out:
#                Series_Title  No_of_Votes
# 0  The Shawshank Redemption      2343110

# %% [markdown]
# It looks like 'The Shawshank Redemption' has the highest number of votes all time with a values of 2,343,110 votes.

# %%
# Movies with the highest votes by year

h_vote_by_year = mv_rating_clean.groupby('Released_Year').max().reset_index()

high_voted_movies = movie_finder(h_vote_by_year['Released_Year'], h_vote_by_year['No_of_Votes'], 
                                 'Released_Year', 'No_of_Votes')
high_voted_movies = high_voted_movies[['Released_Year', 'Series_Title', 'No_of_Votes']].set_index('Released_Year')
print(high_voted_movies.to_string())
# Out:
#                                                                        Series_Title  No_of_Votes
# Released_Year
# 1921                                                                        The Kid       113314
# 1924                                                                   Sherlock Jr.        41985
# 1925                                                                  The Gold Rush       101053
# 1926                                                                    The General        81156
# 1927                                                  Sunrise: A Song of Two Humans        46865
# 1928                                                     La passion de Jeanne d'Arc        47676
# 1930                                                 All Quiet on the Western Front        57318
# 1931                                                                    City Lights       167839
# 1932                                              Scarface: The Shame of the Nation        25312
# 1933                                                                      King Kong        78991
# 1934                                                          It Happened One Night        94016
# 1935                                                           A Night at the Opera        30580
# 1936                                                                   Modern Times       217881
# 1938                                                               Bringing Up Baby        55163
# 1939                                                               The Wizard of Oz       371379
# 1940                                                             The Great Dictator       203150
# 1941                                                                   Citizen Kane       403351
# 1942                                                                     Casablanca       522093
# 1943                                                              Shadow of a Doubt        59556
# 1944                                                               Double Indemnity       143525
# 1945                                                                Brief Encounter        35601
# 1946                                                          It's a Wonderful Life       405801
# 1948                                                                           Rope       129783
# 1949                                                                  The Third Man       158731
# 1950                                                                   Sunset Blvd.       201632
# 1951                                                           Strangers on a Train       123341
# 1952                                                            Singin' in the Rain       218957
# 1953                                                          Le salaire de la peur        54588
# 1954                                                                    Rear Window       444074
# 1955                                                          Rebel Without a Cause        83363
# 1956                                                                    The Killing        81702
# 1957                                                                   12 Angry Men       689845
# 1958                                                                        Vertigo       364368
# 1959                                                             North by Northwest       299198
# 1960                                                                         Psycho       604211
# 1961                                                         Breakfast at Tiffany's       166544
# 1962                                                          To Kill a Mockingbird       293811
# 1963                                                               The Great Escape       224730
# 1964           Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb       450474
# 1965                                                     Per qualche dollaro in più       232772
# 1966                                                Il buono, il brutto, il cattivo       688390
# 1967                                                                   The Graduate       253676
# 1968                                                          2001: A Space Odyssey       603517
# 1969                                             Butch Cassidy and the Sundance Kid       201888
# 1970                                                                         Patton        93741
# 1971                                                             A Clockwork Orange       757904
# 1972                                                                  The Godfather      1620367
# 1973                                                                   The Exorcist       362393
# 1974                                                         The Godfather: Part II      1129952
# 1975                                                One Flew Over the Cuckoo's Nest       918088
# 1976                                                                    Taxi Driver       724636
# 1977                                                                      Star Wars      1231473
# 1978                                                                The Deer Hunter       311361
# 1979                                                                          Alien       787806
# 1980                                 Star Wars: Episode V - The Empire Strikes Back      1159315
# 1981                                                        Raiders of the Lost Ark       884112
# 1982                                                                   Blade Runner       693827
# 1983                                     Star Wars: Episode VI - Return of the Jedi       950470
# 1984                                                                 The Terminator       799795
# 1985                                                             Back to the Future      1058081
# 1986                                                                         Aliens       652719
# 1987                                                              Full Metal Jacket       675146
# 1988                                                                       Die Hard       793164
# 1989                                             Indiana Jones and the Last Crusade       692366
# 1990                                                                     Goodfellas      1020727
# 1991                                                       The Silence of the Lambs      1270197
# 1992                                                                 Reservoir Dogs       918562
# 1993                                                               Schindler's List      1213505
# 1994                                                       The Shawshank Redemption      2343110
# 1995                                                                          Se7en      1445096
# 1996                                                                  Trainspotting       634716
# 1997                                                                        Titanic      1046089
# 1998                                                            Saving Private Ryan      1235804
# 1999                                                                     Fight Club      1854740
# 2000                                                                      Gladiator      1341460
# 2001                              The Lord of the Rings: The Fellowship of the Ring      1661481
# 2002                                          The Lord of the Rings: The Two Towers      1485555
# 2003                                  The Lord of the Rings: The Return of the King      1642758
# 2004                                          Eternal Sunshine of the Spotless Mind       911664
# 2005                                                                  Batman Begins      1308302
# 2006                                                                   The Prestige      1190259
# 2007                                                         No Country for Old Men       856916
# 2008                                                                The Dark Knight      2303232
# 2009                                                           Inglourious Basterds      1267869
# 2010                                                                      Inception      2067042
# 2011                                   Harry Potter and the Deathly Hallows: Part 2       764493
# 2012                                                          The Dark Knight Rises      1516346
# 2013                                                        The Wolf of Wall Street      1187498
# 2014                                                                   Interstellar      1512360
# 2015                                                             Mad Max: Fury Road       882316
# 2016                                                                       Deadpool       902669
# 2017                                                                          Logan       647884
# 2018                                                         Avengers: Infinity War       834477
# 2019                                                                          Joker       939252
# 2020                                                                           Soul       159171

# %%
# Plotting line graph of number of votes over time grouped by year

plt.plot(high_voted_movies.index, high_voted_movies['No_of_Votes'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Number of Votes')
plt.title('Highest Number of Votes Over Time')
plt.grid()
plt.show()

# %% [markdown]
# As seen above, the overall trend of the highest number of votes increases over time and drops starting from approximately the year 2010 up to 2020.
#
# Now I'm going to take the median number of votes in each year and plot it to compare with the graph above.

# %%
# Median number of votes grouped by year

median_vote_by_year = mv_rating_clean.groupby('Released_Year').median().reset_index()

plt.plot(median_vote_by_year['Released_Year'], median_vote_by_year['No_of_Votes'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Number of Votes')
plt.title('Median Number of Votes Over Time')
plt.grid()
plt.show()

# %% [markdown]
# It looks like both the median and the max number of votes graphs share the same overall increasing trend and drops sharply by approxiamtely 2010 to 2020.
#
# The number of votes in 2020 is really low comapred to other votes in the 21st century. This might actually happen due to the Covid-19 pandemic since people are told to stay at home as much as possible and not go to watch movies at the cinema. This means that fewer people were able to vote since they didn't watch the movie. Unfortunately, this can't be proven since I don't have data about the number of people going to the cinema in the 21st century. In my opinion, getting only the data for the year 2020 will be pointless since I can't use it to compare it with the graph above because I would need the data of cinema visits at least from the year 2000.

# %% [markdown]
# #### Highest Runtime
#
# In this part, I will find out which movies have the highest all time runtime and movies that have the highest runtime grouped by its release year.

# %%
# Movie with the highest all time runtime

at_high_rt = mv_rating_clean[mv_rating_clean['Runtime_min'] == mv_rating_clean['Runtime_min'].max()]
at_high_rt[['Released_Year', 'Series_Title', 'Runtime_min']]
# Out:
#      Released_Year        Series_Title  Runtime_min
# 140           2012  Gangs of Wasseypur          321

# %%
# Movie with the highest runtime grouped by year

rt_by_year = mv_rating_clean.groupby('Released_Year').max().reset_index()
high_rt_by_year = movie_finder(rt_by_year['Released_Year'], rt_by_year['Runtime_min'], 'Released_Year', 'Runtime_min')
print(high_rt_by_year[['Released_Year', 'Series_Title', 'Runtime_min']].set_index('Released_Year').to_string())
# Out:
#                                                 Series_Title  Runtime_min
# Released_Year
# 1921                                                 The Kid           68
# 1924                                            Sherlock Jr.           45
# 1925                                           The Gold Rush           95
# 1926                                             The General           67
# 1927                           Sunrise: A Song of Two Humans           94
# 1928                              La passion de Jeanne d'Arc          110
# 1930                          All Quiet on the Western Front          152
# 1931                       M - Eine Stadt sucht einen Mörder          117
# 1932                       Scarface: The Shame of the Nation           93
# 1933                                               King Kong          100
# 1934                                   It Happened One Night          105
# 1935                                    A Night at the Opera           96
# 1936                                            Modern Times           87
# 1938                            The Adventures of Robin Hood          102
# 1938                                        Bringing Up Baby          102
# 1939                                      Gone with the Wind          238
# 1940                                                 Rebecca          130
# 1941                                            Citizen Kane          119
# 1942                                              Casablanca          102
# 1943                                       Shadow of a Doubt          108
# 1944                                        Double Indemnity          107
# 1945                                        The Lost Weekend          101
# 1946                             The Best Years of Our Lives          170
# 1948                                               Red River          133
# 1949                                Kind Hearts and Coronets          106
# 1950                                           All About Eve          138
# 1951                                A Streetcar Named Desire          122
# 1952                                           The Quiet Man          129
# 1953                                        Tôkyô monogatari          136
# 1954                                    Shichinin no samurai          207
# 1955                                            East of Eden          118
# 1956                                    The Ten Commandments          220
# 1957                            The Bridge on the River Kwai          161
# 1958                                                 Vertigo          128
# 1959                                                 Ben-Hur          212
# 1960                                               Spartacus          197
# 1961                                   Judgment at Nuremberg          179
# 1962                                      Lawrence of Arabia          228
# 1963                                        The Great Escape          172
# 1964                                            My Fair Lady          170
# 1965                                          Doctor Zhivago          197
# 1966                                           Andrei Rublev          205
# 1967                                          Cool Hand Luke          127
# 1968                            Once Upon a Time in the West          165
# 1969                                          The Wild Bunch          145
# 1970                                                  Patton          172
# 1971                                     Fiddler on the Roof          181
# 1972                                           The Godfather          175
# 1973                                                Papillon          151
# 1974                                  The Godfather: Part II          202
# 1975                                                  Sholay          204
# 1976                                             The Message          177
# 1977                      Close Encounters of the Third Kind          138
# 1978                                         The Deer Hunter          183
# 1979                                                 Stalker          162
# 1980                                               Kagemusha          180
# 1981                                                Das Boot          149
# 1982                                                  Gandhi          191
# 1983                                         The Right Stuff          193
# 1984                             Once Upon a Time in America          229
# 1985                                                     Ran          162
# 1986                                                  Aliens          137
# 1987                                        The Last Emperor          163
# 1988                                   Nuovo Cinema Paradiso          155
# 1989                                      Dead Poets Society          128
# 1990                                      Dances with Wolves          181
# 1991                                                     JFK          189
# 1992                                               Malcolm X          202
# 1993                                        Schindler's List          195
# 1994                                         Andaz Apna Apna          160
# 1995                             Dilwale Dulhania Le Jayenge          189
# 1996                                                  Hamlet          242
# 1997                                                 Titanic          194
# 1998                                       The Thin Red Line          170
# 1999                                          The Green Mile          189
# 2000                                              Hera Pheri          156
# 2001                       Lagaan: Once Upon a Time in India          224
# 2002                   The Lord of the Rings: The Two Towers          179
# 2003           The Lord of the Rings: The Return of the King          201
# 2004                                  Swades: We, the People          210
# 2005                     Harry Potter and the Goblet of Fire          157
# 2006                                         Rang De Basanti          167
# 2007                                        Taare Zameen Par          165
# 2008                     The Curious Case of Benjamin Button          166
# 2009                                                3 Idiots          170
# 2010                                         My Name Is Khan          165
# 2011                                                Rockstar          159
# 2012                                      Gangs of Wasseypur          321
# 2013                                      Bhaag Milkha Bhaag          186
# 2014                                            Interstellar          169
# 2015                                       The Hateful Eight          168
# 2016                            M.S. Dhoni: The Untold Story          184
# 2017                             Baahubali 2: The Conclusion          167
# 2018                                        K.G.F: Chapter 1          156
# 2019                                            The Irishman          209
# 2020                                                Hamilton          160

# %%
# Plotting highest movie runtime over time

plt.plot(high_rt_by_year['Released_Year'], high_rt_by_year['Runtime_min'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Run Time (min)')
plt.title('Highest Run Time Over Time')
plt.grid()
plt.show()

# %%
# Plotting median movie runtime over time

median_rt_by_year = mv_rating_clean.groupby('Released_Year').median().reset_index()

plt.plot(median_rt_by_year['Released_Year'], median_rt_by_year['Runtime_min'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Run Time (min)')
plt.title('Median Run Time Over Time')
plt.grid()
plt.show()

# %% [markdown]
# From the results of both graphs, it can be observed that as time goes by, the run time of movies increases.

# %% [markdown]
# #### Highest Gross
#
# For this part, I'll find movies with the highest gross all time and movies with the highest gross grouped by its release year.

# %%
# Movies with the highest all time gross

at_high_g = mv_rating_clean[mv_rating_clean['Gross_num'] == mv_rating_clean['Gross_num'].max()]
at_high_g[['Released_Year', 'Series_Title', 'Gross_num']]
# Out:
#      Released_Year                                Series_Title  Gross_num
# 477           2015  Star Wars: Episode VII - The Force Awakens  936662225

# %%
# Movies with the highest gross grouped by year

gr_high_by_year = mv_rating_clean.groupby('Released_Year').max().reset_index()
gross_high_by_year = movie_finder(gr_high_by_year['Released_Year'], gr_high_by_year['Gross_num'], 'Released_Year', 'Gross_num')
print(gross_high_by_year[['Released_Year', 'Series_Title', 'Gross_num']].set_index('Released_Year').to_string())
# Out:
#                                                  Series_Title  Gross_num
# Released_Year
# 1921                                                  The Kid    5450000
# 1924                                             Sherlock Jr.     977375
# 1925                                            The Gold Rush    5450000
# 1926                                              The General    1033895
# 1927                            Sunrise: A Song of Two Humans     539540
# 1928                                               The Circus   23530892
# 1930                           All Quiet on the Western Front    3270000
# 1931                                             Frankenstein   23530892
# 1932                        Scarface: The Shame of the Nation   23530892
# 1933                                        The Invisible Man   23530892
# 1934                                             The Thin Man   23530892
# 1935                                     A Night at the Opera    2537520
# 1936                                             Modern Times     163245
# 1938                                         Bringing Up Baby   23530892
# 1939                                       Gone with the Wind  198676459
# 1940                                                 Fantasia   76408097
# 1941                                             Citizen Kane    1585634
# 1942                                       To Be or Not to Be   23530892
# 1943                                        Shadow of a Doubt   23530892
# 1944                                     To Have and Have Not   23530892
# 1945                                          Brief Encounter   23530892
# 1946                              The Best Years of Our Lives   23650000
# 1948                                                     Rope   23530892
# 1948                                                Red River   23530892
# 1949                                 Kind Hearts and Coronets   23530892
# 1950                                             Sunset Blvd.   23530892
# 1950                                                   Harvey   23530892
# 1951                            The Day the Earth Stood Still   23530892
# 1952                                            The Quiet Man   10550000
# 1953                                    From Here to Eternity   30500000
# 1954                                              Rear Window   36764313
# 1955                                             East of Eden   23530892
# 1955                                    Rebel Without a Cause   23530892
# 1956                                     The Ten Commandments   93740000
# 1957                             The Bridge on the River Kwai   44908000
# 1958                                    Cat on a Hot Tin Roof   17570324
# 1959                                                  Ben-Hur   74700000
# 1960                                                   Psycho   32000000
# 1961                                    Judgment at Nuremberg   23530892
# 1961                                   Breakfast at Tiffany's   23530892
# 1962                                       Lawrence of Arabia   44824144
# 1963                                                  Charade   13474588
# 1964                                             Mary Poppins  102272727
# 1965                                       The Sound of Music  163214286
# 1966                                    A Man for All Seasons   28350000
# 1967                                          The Jungle Book  141843612
# 1968                                    2001: A Space Odyssey   56954992
# 1969                       Butch Cassidy and the Sundance Kid  102308889
# 1970                                                   Patton   61700000
# 1971                                      Fiddler on the Roof   80500000
# 1972                                            The Godfather  134966411
# 1973                                             The Exorcist  232906145
# 1974                                          Blazing Saddles  119500000
# 1975                                                     Jaws  260000000
# 1976                                                    Rocky  117235247
# 1977                                                Star Wars  322740140
# 1978                                          The Deer Hunter   48979328
# 1979                                        Kramer vs. Kramer  106260000
# 1980           Star Wars: Episode V - The Empire Strikes Back  290475067
# 1981                                  Raiders of the Lost Ark  248159971
# 1982                               E.T. the Extra-Terrestrial  435110554
# 1983               Star Wars: Episode VI - Return of the Jedi  309125409
# 1984                                             Ghostbusters  238632124
# 1985                                       Back to the Future  210609762
# 1986                                                  Platoon  138530565
# 1987                                         The Untouchables   76270454
# 1988                                                 Rain Man  178800000
# 1989                       Indiana Jones and the Last Crusade  197171806
# 1990                                               Home Alone  285761243
# 1991                                     Beauty and the Beast  218967620
# 1992                                                  Aladdin  217350219
# 1993                                            Jurassic Park  402453882
# 1994                                            The Lion King  422783777
# 1995                                                Toy Story  191796233
# 1996                                              Primal Fear   56116183
# 1997                                                  Titanic  659325379
# 1998                                      Saving Private Ryan  216540909
# 1999                                          The Sixth Sense  293506292
# 2000                                                Cast Away  233632142
# 2001                    Harry Potter and the Sorcerer's Stone  317575550
# 2002                    The Lord of the Rings: The Two Towers  342551365
# 2003                                             Finding Nemo  380843261
# 2004                                          The Incredibles  261441092
# 2005                      Harry Potter and the Goblet of Fire  290013036
# 2006                                                      300  210614939
# 2007                                     The Bourne Ultimatum  227471070
# 2008                                          The Dark Knight  534858444
# 2009                                                   Avatar  760507625
# 2010                                              Toy Story 3  415004880
# 2011             Harry Potter and the Deathly Hallows: Part 2  381011219
# 2012                                             The Avengers  623279547
# 2013                                                  Gravity  274092705
# 2014                                  Guardians of the Galaxy  333176600
# 2015               Star Wars: Episode VII - The Force Awakens  936662225
# 2016                                                Rogue One  532177324
# 2017                           Guardians of the Galaxy Vol. 2  389813101
# 2018                                   Avengers: Infinity War  678815482
# 2019                                        Avengers: Endgame  858373000
# 2020                                                 Hamilton   23530892
# 2020                                          Soorarai Pottru   23530892
# 2020                                                     Soul   23530892
# 2020                                              Dil Bechara   23530892
# 2020                               The Trial of the Chicago 7   23530892

# %%
# Plotting highest gross movies over time

plt.plot(gr_high_by_year['Released_Year'], gr_high_by_year['Gross_num'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Gross (USD)')
plt.title('Highest Gross Over Time')
plt.grid()
plt.show()

# %%
# Plotting median gross movies over time

median_gr_by_year = mv_rating_clean.groupby('Released_Year').median().reset_index()

plt.plot(median_gr_by_year['Released_Year'], median_gr_by_year['Gross_num'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Gross (USD)')
plt.title('Median Gross Over Time')
plt.grid()
plt.show()

# %% [markdown]
# From the graphs above, it seems like the trend of the highest all time movie gross increases exponentially over time. On the other hand the median trend of gross over time increases only by a little bit. A total of three outliers can also be observed in between the year 1960 and the 2010s.

# %% [markdown]
# #### Lowest IMDB Rating
#
# For this part, I'll find movies with the lowest all time imdb rating and movies with the lowest imdb rating grouped by year.

# %%
# Movies with the lowest all time imdb rating

at_low_rat = mv_rating_clean[mv_rating_clean['IMDB_Rating'] == mv_rating_clean['IMDB_Rating'].min()]
print(at_low_rat[['Released_Year', 'Series_Title', 'IMDB_Rating']].set_index('Released_Year').to_string())
# Out:
#                                                  Series_Title  IMDB_Rating
# Released_Year
# 2019                                              Dark Waters          7.6
# 2018                                                Searching          7.6
# 2019                         Once Upon a Time... in Hollywood          7.6
# 2017                                                 Nelyubov          7.6
# 2017                                      The Florida Project          7.6
# 2019                                               Just Mercy          7.6
# 2017                                                   Gifted          7.6
# 2019                                 The Peanut Butter Falcon          7.6
# 2015                                                  Mustang          7.6
# 2017                           Guardians of the Galaxy Vol. 2          7.6
# 2017                                              Baby Driver          7.6
# 2017                                           Only the Brave          7.6
# 2015                                          Bridge of Spies          7.6
# 2018                                            Incredibles 2          7.6
# 2016                                                    Moana          7.6
# 2015                                                  Sicario          7.6
# 2015                                                    Creed          7.6
# 2014                                                 Leviafan          7.6
# 2016                                       Hell or High Water          7.6
# 2013                                                Philomena          7.6
# 2014                           Dawn of the Planet of the Apes          7.6
# 2011                                             Serbuan maut          7.6
# 2012                                             End of Watch          7.6
# 2010                                  Kari-gurashi no Arietti          7.6
# 2018                                           A Star Is Born          7.6
# 2010                                                True Grit          7.6
# 2010                                                   Hævnen          7.6
# 2010                                            Despicable Me          7.6
# 2011                                                    50/50          7.6
# 2010                                                 Kick-Ass          7.6
# 2011                                                Moneyball          7.6
# 2011                                       La piel que habito          7.6
# 2009                                               Zombieland          7.6
# 2009                                          Sherlock Holmes          7.6
# 2009                                           The Blind Side          7.6
# 2007                                              The Visitor          7.6
# 2008                                             Seven Pounds          7.6
# 2007                                         Eastern Promises          7.6
# 2007                                                 Stardust          7.6
# 2006                                               Inside Man          7.6
# 2007                                           Gone Baby Gone          7.6
# 2007                                           La Vie En Rose          7.6
# 2006                                             Huo Yuan Jia          7.6
# 2006                                          The Illusionist          7.6
# 2009                   Harry Potter and the Half-Blood Prince          7.6
# 2006                                                      300          7.6
# 2005                                              Match Point          7.6
# 2009                                                 Watchmen          7.6
# 2005                                              Lord of War          7.6
# 2004                                                      Saw          7.6
# 2008                                     Synecdoche, New York          7.6
# 2004                                          Mysterious Skin          7.6
# 2003                                           Jeux d'enfants          7.6
# 2004                          Un long dimanche de fiançailles          7.6
# 2003                                        The Station Agent          7.6
# 2003                                                 21 Grams          7.6
# 2002                                      Boksuneun naui geot          7.6
# 2004                                        Finding Neverland          7.6
# 2002                                                25th Hour          7.6
# 2004                                     The Butterfly Effect          7.6
# 2002                                         28 Days Later...          7.6
# 2001                                     The Royal Tenenbaums          7.6
# 2001                                        Y tu mamá también          7.6
# 2001                    Harry Potter and the Sorcerer's Stone          7.6
# 2001                                               The Others          7.6
# 2001                                                     Blow          7.6
# 2001                                       Enemy at the Gates          7.6
# 2002                                          Minority Report          7.6
# 1999                                            The Hurricane          7.6
# 2000                                          American Psycho          7.6
# 1998                                               Lola rennt          7.6
# 1998                                        The Thin Red Line          7.6
# 1998                                                    Mulan          7.6
# 1998                           Fear and Loathing in Las Vegas          7.6
# 1997                                              Funny Games          7.6
# 1998                                                Dark City          7.6
# 1996                                                 Sleepers          7.6
# 1997                                             Lost Highway          7.6
# 1995                                    Sense and Sensibility          7.6
# 1995                               Die Hard: With a Vengeance          7.6
# 1995                                                 Dead Man          7.6
# 1995                            The Bridges of Madison County          7.6
# 1995                                                Apollo 13          7.6
# 1994                                    Trois couleurs: Blanc          7.6
# 1993                                             Falling Down          7.6
# 1993                                       Dazed and Confused          7.6
# 1992                                          My Cousin Vinny          7.6
# 1991                                        Omohide poro poro          7.6
# 1991                                             Delicatessen          7.6
# 1990                                               Home Alone          7.6
# 1990                                  The Godfather: Part III          7.6
# 1989                                  When Harry Met Sally...          7.6
# 1989                                       The Little Mermaid          7.6
# 1988           The Naked Gun: From the Files of Police Squad!          7.6
# 1987                             Planes, Trains & Automobiles          7.6
# 1987                                            Lethal Weapon          7.6
# 1984                                             Blood Simple          7.6
# 1981                                           On Golden Pond          7.6
# 1981                                                Mad Max 2          7.6
# 1979                                             The Warriors          7.6
# 1979                                         The Muppet Movie          7.6
# 1979                                     Escape from Alcatraz          7.6
# 1978                                           Watership Down          7.6
# 1978                                         Midnight Express          7.6
# 1977                       Close Encounters of the Third Kind          7.6
# 1973                                         The Long Goodbye          7.6
# 1971                                             Giù la testa          7.6
# 1970                                           Kelly's Heroes          7.6
# 1967                                          The Jungle Book          7.6
# 1966                                                   Blowup          7.6
# 1964                                       A Hard Day's Night          7.6
# 1961                                   Breakfast at Tiffany's          7.6
# 1956                                                    Giant          7.6
# 1953                                    From Here to Eternity          7.6

# %%
# Movies with the lowest imdb rating grouped by year

low_rt_by_year = mv_rating_clean.groupby('Released_Year').min().reset_index()
lw_rt_by_year = movie_finder(low_rt_by_year['Released_Year'], low_rt_by_year['IMDB_Rating'], 'Released_Year', 'IMDB_Rating')
print(lw_rt_by_year[['Released_Year', 'Series_Title', 'IMDB_Rating']].set_index('Released_Year').to_string())
# Out:
#                                                  Series_Title  IMDB_Rating
# Released_Year
# 1921                                                  The Kid          8.3
# 1924                                             Sherlock Jr.          8.2
# 1925                                            The Gold Rush          8.2
# 1926                                              The General          8.1
# 1927                            Sunrise: A Song of Two Humans          8.1
# 1928                               La passion de Jeanne d'Arc          8.1
# 1928                                               The Circus          8.1
# 1930                           All Quiet on the Western Front          8.0
# 1931                                             Frankenstein          7.8
# 1932                        Scarface: The Shame of the Nation          7.8
# 1933                                        The Invisible Man          7.7
# 1934                                             The Thin Man          8.0
# 1935                                     A Night at the Opera          7.9
# 1936                                             Modern Times          8.5
# 1938                                         Bringing Up Baby          7.8
# 1939                                               Stagecoach          7.8
# 1940                                                 Fantasia          7.7
# 1941                                             Citizen Kane          8.3
# 1942                                       To Be or Not to Be          8.2
# 1943                                        Shadow of a Doubt          7.8
# 1944                                     To Have and Have Not          7.8
# 1945                                         The Lost Weekend          7.9
# 1946                                                    Gilda          7.7
# 1948                                                Red River          7.8
# 1949                                 Kind Hearts and Coronets          8.0
# 1950                                                   Harvey          7.9
# 1951                            The Day the Earth Stood Still          7.7
# 1951                                        The African Queen          7.7
# 1952                                            The Quiet Man          7.7
# 1953                                    From Here to Eternity          7.6
# 1954                                                  Sabrina          7.7
# 1955                                    Rebel Without a Cause          7.7
# 1956                                                    Giant          7.6
# 1957                                   Sweet Smell of Success          8.0
# 1958                                            Touch of Evil          8.0
# 1958                                    Cat on a Hot Tin Roof          8.0
# 1959                                                Rio Bravo          8.0
# 1960                                    The Magnificent Seven          7.7
# 1961                                   Breakfast at Tiffany's          7.6
# 1962                                                Cape Fear          7.7
# 1963                                                The Birds          7.7
# 1964                                       A Hard Day's Night          7.6
# 1965                                       The Sound of Music          8.0
# 1965                                           Doctor Zhivago          8.0
# 1966                                                   Blowup          7.6
# 1967                                          The Jungle Book          7.6
# 1968                                        Where Eagles Dare          7.7
# 1968                                           The Odd Couple          7.7
# 1969                                          Midnight Cowboy          7.8
# 1970                                           Kelly's Heroes          7.6
# 1971                                             Giù la testa          7.6
# 1972                                              Deliverance          7.7
# 1973                                         The Long Goodbye          7.6
# 1974                       The Taking of Pelham One Two Three          7.7
# 1974                                          Blazing Saddles          7.7
# 1975                                           Love and Death          7.7
# 1976                                             Le locataire          7.7
# 1977                       Close Encounters of the Third Kind          7.6
# 1978                                           Watership Down          7.6
# 1978                                         Midnight Express          7.6
# 1979                                             The Warriors          7.6
# 1979                                         The Muppet Movie          7.6
# 1979                                     Escape from Alcatraz          7.6
# 1980                                          Ordinary People          7.7
# 1980                                                Airplane!          7.7
# 1981                                           On Golden Pond          7.6
# 1981                                                Mad Max 2          7.6
# 1982                                              The Verdict          7.7
# 1982                          Star Trek II: The Wrath of Khan          7.7
# 1982                                              First Blood          7.7
# 1983                                                    Zelig          7.7
# 1984                                             Blood Simple          7.6
# 1985                                 The Purple Rose of Cairo          7.7
# 1985                                              After Hours          7.7
# 1986                                        Der Name der Rose          7.7
# 1986                                              Blue Velvet          7.7
# 1987                             Planes, Trains & Automobiles          7.6
# 1987                                            Lethal Weapon          7.6
# 1988           The Naked Gun: From the Files of Police Squad!          7.6
# 1989                                  When Harry Met Sally...          7.6
# 1989                                       The Little Mermaid          7.6
# 1990                                               Home Alone          7.6
# 1990                                  The Godfather: Part III          7.6
# 1991                                        Omohide poro poro          7.6
# 1991                                             Delicatessen          7.6
# 1992                                          My Cousin Vinny          7.6
# 1993                                             Falling Down          7.6
# 1993                                       Dazed and Confused          7.6
# 1994                                    Trois couleurs: Blanc          7.6
# 1995                                    Sense and Sensibility          7.6
# 1995                               Die Hard: With a Vengeance          7.6
# 1995                                                 Dead Man          7.6
# 1995                            The Bridges of Madison County          7.6
# 1995                                                Apollo 13          7.6
# 1996                                                 Sleepers          7.6
# 1997                                              Funny Games          7.6
# 1997                                             Lost Highway          7.6
# 1998                                               Lola rennt          7.6
# 1998                                        The Thin Red Line          7.6
# 1998                                                    Mulan          7.6
# 1998                           Fear and Loathing in Las Vegas          7.6
# 1998                                                Dark City          7.6
# 1999                                            The Hurricane          7.6
# 2000                                          American Psycho          7.6
# 2001                                     The Royal Tenenbaums          7.6
# 2001                                        Y tu mamá también          7.6
# 2001                    Harry Potter and the Sorcerer's Stone          7.6
# 2001                                               The Others          7.6
# 2001                                                     Blow          7.6
# 2001                                       Enemy at the Gates          7.6
# 2002                                      Boksuneun naui geot          7.6
# 2002                                                25th Hour          7.6
# 2002                                         28 Days Later...          7.6
# 2002                                          Minority Report          7.6
# 2003                                           Jeux d'enfants          7.6
# 2003                                        The Station Agent          7.6
# 2003                                                 21 Grams          7.6
# 2004                                                      Saw          7.6
# 2004                                          Mysterious Skin          7.6
# 2004                          Un long dimanche de fiançailles          7.6
# 2004                                        Finding Neverland          7.6
# 2004                                     The Butterfly Effect          7.6
# 2005                                              Match Point          7.6
# 2005                                              Lord of War          7.6
# 2006                                               Inside Man          7.6
# 2006                                             Huo Yuan Jia          7.6
# 2006                                          The Illusionist          7.6
# 2006                                                      300          7.6
# 2007                                              The Visitor          7.6
# 2007                                         Eastern Promises          7.6
# 2007                                                 Stardust          7.6
# 2007                                           Gone Baby Gone          7.6
# 2007                                           La Vie En Rose          7.6
# 2008                                             Seven Pounds          7.6
# 2008                                     Synecdoche, New York          7.6
# 2009                                               Zombieland          7.6
# 2009                                          Sherlock Holmes          7.6
# 2009                                           The Blind Side          7.6
# 2009                   Harry Potter and the Half-Blood Prince          7.6
# 2009                                                 Watchmen          7.6
# 2010                                  Kari-gurashi no Arietti          7.6
# 2010                                                True Grit          7.6
# 2010                                                   Hævnen          7.6
# 2010                                            Despicable Me          7.6
# 2010                                                 Kick-Ass          7.6
# 2011                                             Serbuan maut          7.6
# 2011                                                    50/50          7.6
# 2011                                                Moneyball          7.6
# 2011                                       La piel que habito          7.6
# 2012                                             End of Watch          7.6
# 2013                                                Philomena          7.6
# 2014                                                 Leviafan          7.6
# 2014                           Dawn of the Planet of the Apes          7.6
# 2015                                                  Mustang          7.6
# 2015                                          Bridge of Spies          7.6
# 2015                                                  Sicario          7.6
# 2015                                                    Creed          7.6
# 2016                                                    Moana          7.6
# 2016                                       Hell or High Water          7.6
# 2017                                                 Nelyubov          7.6
# 2017                                      The Florida Project          7.6
# 2017                                                   Gifted          7.6
# 2017                           Guardians of the Galaxy Vol. 2          7.6
# 2017                                              Baby Driver          7.6
# 2017                                           Only the Brave          7.6
# 2018                                                Searching          7.6
# 2018                                            Incredibles 2          7.6
# 2018                                           A Star Is Born          7.6
# 2019                                              Dark Waters          7.6
# 2019                         Once Upon a Time... in Hollywood          7.6
# 2019                                               Just Mercy          7.6
# 2019                                 The Peanut Butter Falcon          7.6
# 2020                               The Trial of the Chicago 7          7.8

# %%
# Plotting lowest imdb rating over time

plt.plot(low_rt_by_year['Released_Year'], low_rt_by_year['IMDB_Rating'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('IMDB Rating')
plt.title('Lowest IMDB Rating Over Time')
plt.grid()
plt.show()

# %% [markdown]
# #### Lowest Meta Score
#
# For this part, I'll find movies with the lowest all time meta score and movies with the lowest meta score grouped by year.

# %%
# Movies with the lowest all time meta score

at_lw_ms = mv_rating_clean[mv_rating_clean['Meta_score'] == mv_rating_clean['Meta_score'].min()]
at_lw_ms[['Released_Year', 'Series_Title', 'Meta_score']]
# Out:
#      Released_Year Series_Title  Meta_score
# 788           2001     I Am Sam        28.0

# %%
# Movies with the lowest meta score grouped by year

lw_ms_by_year = mv_rating_clean.groupby('Released_Year').min().reset_index()
lwst_ms_by_year = movie_finder(lw_ms_by_year['Released_Year'], lw_ms_by_year['Meta_score'], 'Released_Year', 'Meta_score')
print(lwst_ms_by_year[['Released_Year', 'Series_Title', 'Meta_score']].set_index('Released_Year').to_string())
# Out:
#                                              Series_Title  Meta_score
# Released_Year
# 1921                                              The Kid        78.0
# 1924                                         Sherlock Jr.        78.0
# 1925                                        The Gold Rush        78.0
# 1926                                          The General        78.0
# 1927                        Sunrise: A Song of Two Humans        78.0
# 1928                           La passion de Jeanne d'Arc        78.0
# 1930                       All Quiet on the Western Front        91.0
# 1931                    M - Eine Stadt sucht einen Mörder        78.0
# 1932                    Scarface: The Shame of the Nation        87.0
# 1933                                    The Invisible Man        87.0
# 1934                                         The Thin Man        86.0
# 1935                                 A Night at the Opera        78.0
# 1936                                         Modern Times        96.0
# 1938                                     Bringing Up Baby        91.0
# 1939                         Mr. Smith Goes to Washington        73.0
# 1940                                   The Great Dictator        78.0
# 1940                                      His Girl Friday        78.0
# 1941                                         Citizen Kane       100.0
# 1942                                   To Be or Not to Be        86.0
# 1943                                    Shadow of a Doubt        94.0
# 1944                                                Laura        78.0
# 1944                                 To Have and Have Not        78.0
# 1945                                     The Lost Weekend        78.0
# 1946                                        The Big Sleep        78.0
# 1946                                                Gilda        78.0
# 1948                                                 Rope        73.0
# 1949                             Kind Hearts and Coronets        78.0
# 1950                                         Sunset Blvd.        78.0
# 1950                                               Harvey        78.0
# 1951                                      Ace in the Hole        72.0
# 1952                                        The Quiet Man        78.0
# 1953                                     Tôkyô monogatari        78.0
# 1954                                              Sabrina        72.0
# 1955                                         East of Eden        72.0
# 1956                                 The Ten Commandments        78.0
# 1957                          Witness for the Prosecution        78.0
# 1958                                Cat on a Hot Tin Roof        84.0
# 1959                                              Ben-Hur        90.0
# 1960                                The Magnificent Seven        74.0
# 1961                                Judgment at Nuremberg        60.0
# 1962                     What Ever Happened to Baby Jane?        75.0
# 1962                                      The Longest Day        75.0
# 1963                                              Charade        83.0
# 1964                              Per un pugno di dollari        65.0
# 1965                                   The Sound of Music        63.0
# 1966                                A Man for All Seasons        72.0
# 1967                                      The Jungle Book        65.0
# 1968                                    Where Eagles Dare        63.0
# 1969                   Butch Cassidy and the Sundance Kid        66.0
# 1970                                       Kelly's Heroes        50.0
# 1971                                     Harold and Maude        62.0
# 1972                                   Viskningar och rop        78.0
# 1972                                               Sleuth        78.0
# 1973                                             Papillon        58.0
# 1974                   The Taking of Pelham One Two Three        68.0
# 1975                                               Sholay        78.0
# 1975                                              Zerkalo        78.0
# 1976                               The Outlaw Josey Wales        69.0
# 1977                                            Star Wars        90.0
# 1977                   Close Encounters of the Third Kind        90.0
# 1978                                     Midnight Express        59.0
# 1979                                         The Warriors        65.0
# 1980                                   The Blues Brothers        60.0
# 1981                                       On Golden Pond        68.0
# 1982                                 Pink Floyd: The Wall        47.0
# 1983           Star Wars: Episode VI - Return of the Jedi        58.0
# 1984                                         Ghostbusters        71.0
# 1985                                          The Goonies        62.0
# 1986                                    Der Name der Rose        54.0
# 1987                                             Predator        45.0
# 1988                                             Rain Man        65.0
# 1988                                  Mississippi Burning        65.0
# 1989                           Back to the Future Part II        57.0
# 1990                              The Godfather: Part III        60.0
# 1991                                 Fried Green Tomatoes        64.0
# 1992                                     Scent of a Woman        59.0
# 1993                                       Bound by Honor        47.0
# 1994                                                 Léon        64.0
# 1995                           Die Hard: With a Vengeance        58.0
# 1996                                          Primal Fear        47.0
# 1997                                    The Fifth Element        52.0
# 1997                                         Lost Highway        52.0
# 1998                       Fear and Loathing in Las Vegas        41.0
# 1999                                  The Boondock Saints        44.0
# 2000                                  Remember the Titans        48.0
# 2001                                             I Am Sam        28.0
# 2002                                  Boksuneun naui geot        56.0
# 2003                                       Jeux d'enfants        45.0
# 2004                                 The Butterfly Effect        30.0
# 2005                                          Adams æbler        51.0
# 2006                                                  300        52.0
# 2007                                       Tropa de Elite        33.0
# 2008                                         Seven Pounds        36.0
# 2009                                       The Blind Side        53.0
# 2010                                              Flipped        45.0
# 2011                                     The Intouchables        57.0
# 2012                    The Hobbit: An Unexpected Journey        58.0
# 2013                                          Kai po che!        40.0
# 2014                         Kingsman: The Secret Service        60.0
# 2015                                    The Hateful Eight        68.0
# 2016                                             Deadpool        65.0
# 2016                                            Rogue One        65.0
# 2017                                               Gifted        60.0
# 2018                                    Bohemian Rhapsody        49.0
# 2019                                        The Gentlemen        51.0
# 2020                           The Trial of the Chicago 7        77.0

# %%
# Plotting lowest meta score over time

plt.plot(lw_ms_by_year['Released_Year'], lw_ms_by_year['Meta_score'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Meta Score')
plt.title('Lowest Meta Score Over Time')
plt.grid()
plt.show()

# %% [markdown]
# #### Lowest Number of Votes
#
# For this part, I'll find movies with the lowest all time no. of votes and movies with the lowest no. of votes grouped by year.

# %%
# Movies with the lowest all time no. of votes

at_low_nv = mv_rating_clean[mv_rating_clean['No_of_Votes'] == mv_rating_clean['No_of_Votes'].min()]
at_low_nv[['Released_Year', 'Series_Title', 'No_of_Votes']]
# Out:
#      Released_Year    Series_Title  No_of_Votes
# 264           1993  Ba wang bie ji        25088

# %%
# Movies with the lowest no. of votes grouped by year

lw_nv_gr = mv_rating_clean.groupby('Released_Year').min().reset_index()
lw_nv_gr_ss = movie_finder(lw_nv_gr['Released_Year'], lw_nv_gr['No_of_Votes'], 'Released_Year', 'No_of_Votes')
print(lw_nv_gr_ss[['Released_Year', 'Series_Title', 'No_of_Votes']].set_index('Released_Year').to_string())
# Out:
#                                                              Series_Title  No_of_Votes
# Released_Year
# 1921                                                              The Kid       113314
# 1924                                                         Sherlock Jr.        41985
# 1925                                                        The Gold Rush       101053
# 1926                                                          The General        81156
# 1927                                        Sunrise: A Song of Two Humans        46865
# 1928                                                           The Circus        30205
# 1930                                       All Quiet on the Western Front        57318
# 1931                                                         Frankenstein        65341
# 1932                                    Scarface: The Shame of the Nation        25312
# 1933                                                    The Invisible Man        30683
# 1934                                                         The Thin Man        26642
# 1935                                                 A Night at the Opera        30580
# 1936                                                         Modern Times       217881
# 1938                                         The Adventures of Robin Hood        47175
# 1939                                                           Stagecoach        43621
# 1940                                                      His Girl Friday        53667
# 1941                                                         Citizen Kane       403351
# 1942                                                   To Be or Not to Be        29915
# 1943                                                    Shadow of a Doubt        59556
# 1944                                                 To Have and Have Not        31053
# 1945                                                     The Lost Weekend        33549
# 1946                                                                Gilda        27991
# 1948                                                            Red River        28167
# 1949                                             Kind Hearts and Coronets        34485
# 1950                                                               Harvey        52573
# 1951                                                      Ace in the Hole        31568
# 1952                                                        The Quiet Man        34677
# 1953                                                From Here to Eternity        43374
# 1954                                                              Sabrina        59415
# 1955                                                         East of Eden        40313
# 1956                                                                Giant        34075
# 1957                                               Sweet Smell of Success        28137
# 1958                                                Cat on a Hot Tin Roof        45062
# 1959                                                            Rio Bravo        56305
# 1960                                                          L'avventura        26542
# 1961                                                        The Innocents        27007
# 1962                                                            Cape Fear        26457
# 1963                                                              Charade        68689
# 1964                                                                 Zulu        35999
# 1965                                                       Doctor Zhivago        69903
# 1966                                                A Man for All Seasons        31222
# 1967                                                        Belle de jour        40274
# 1968                                                   The Lion in Winter        29003
# 1969                                                       The Wild Bunch        77401
# 1970                                                       Il conformista        27067
# 1971                                                         Giù la testa        30144
# 1972                                                   Viskningar och rop        30206
# 1973                                                   La planète sauvage        25229
# 1974                                   The Taking of Pelham One Two Three        26729
# 1975                                                       Love and Death        36037
# 1976                                                         Le locataire        39889
# 1977                                   Close Encounters of the Third Kind       184966
# 1978                                                          Höstsonaten        26875
# 1979                                   Rupan sansei: Kariosutoro no shiro        27014
# 1980                                                            Kagemusha        32195
# 1981                                                       On Golden Pond        27650
# 1982                                                         Fitzcarraldo        31595
# 1983                                                                Zelig        39881
# 1984                                                   The Killing Fields        51585
# 1985                                             The Purple Rose of Cairo        47102
# 1986                                                          Down by Law        47834
# 1987                                                Au revoir les enfants        31163
# 1988                                                       Dom za vesanje        26402
# 1989                                                  Dip huet seung hung        45624
# 1990                                                           Awakenings       125276
# 1991                                                    Omohide poro poro        27071
# 1992                                                     Lat sau san taam        46700
# 1993                                                       Ba wang bie ji        25088
# 1994                                                   Once Were Warriors        31590
# 1995                                                        Do lok tin si        26429
# 1996                                                               Hamlet        35991
# 1997           Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni        38847
# 1998                                                    Central do Brasil        36419
# 1999                                                   The Straight Story        82002
# 2000                                          Vampire Hunter D: Bloodlust        29210
# 2001                                            Hedwig and the Angry Inch        31957
# 2002                                                The Magdalene Sisters        25938
# 2003                                                    Tôkyô goddofâzâzu        31658
# 2004                                                Taegukgi hwinalrimyeo        37820
# 2005                                                          Joyeux Noël        28003
# 2006                                                     Efter brylluppet        32001
# 2007                                                          The Visitor        41544
# 2008                                                            Okuribito        48582
# 2009                                                                Dev.D        28749
# 2010                                                               Hævnen        38491
# 2011                                                             Rockstar        39501
# 2012                                                     Paan Singh Tomar        33237
# 2013                                                             Drishyam        30722
# 2014                                                       Omoide no Mânî        32798
# 2015                                                               Talvar        31142
# 2016                                                          Udta Punjab        27175
# 2017                                                         Vikram Vedha        28401
# 2018                                                                Raazi        25344
# 2019                                                       Sound of Metal        27187
# 2020                                                      Soorarai Pottru        54995

# %%
# Plotting lowest no. of votes over time

plt.plot(lw_nv_gr['Released_Year'], lw_nv_gr['No_of_Votes'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('No. of Votes')
plt.title('Lowest Number of Votes Over Time')
plt.grid()
plt.show()

# %% [markdown]
# #### Lowest Runtime
#
# For this part, I'll find movies with the lowest all time run time and movies with the lowest run time grouped by year.

# %%
# Movies with the lowest all time runtime

at_lw_rt = mv_rating_clean[mv_rating_clean['Runtime_min'] == mv_rating_clean['Runtime_min'].min()]
at_lw_rt[['Released_Year', 'Series_Title', 'Runtime_min']]
# Out:
#      Released_Year  Series_Title  Runtime_min
# 194           1924  Sherlock Jr.           45

# %%
# Movies with the lowest no. of votes grouped by year

lw_rt_by_year = mv_rating_clean.groupby('Released_Year').min().reset_index()
lw_rt_by_year_ss = movie_finder(lw_rt_by_year['Released_Year'], lw_rt_by_year['Runtime_min'], 'Released_Year', 'Runtime_min')
print(lw_rt_by_year_ss[['Released_Year', 'Series_Title', 'Runtime_min']].set_index('Released_Year').to_string())
# Out:
#                                                  Series_Title  Runtime_min
# Released_Year
# 1921                                                  The Kid           68
# 1924                                             Sherlock Jr.           45
# 1925                                            The Gold Rush           95
# 1926                                              The General           67
# 1927                            Sunrise: A Song of Two Humans           94
# 1928                                               The Circus           72
# 1930                           All Quiet on the Western Front          152
# 1931                                             Frankenstein           70
# 1932                        Scarface: The Shame of the Nation           93
# 1933                                        The Invisible Man           71
# 1934                                             The Thin Man           91
# 1935                                     A Night at the Opera           96
# 1936                                             Modern Times           87
# 1938                             The Adventures of Robin Hood          102
# 1938                                         Bringing Up Baby          102
# 1939                                               Stagecoach           96
# 1940                                          His Girl Friday           92
# 1941                                             Citizen Kane          119
# 1942                                       To Be or Not to Be           99
# 1943                                        Shadow of a Doubt          108
# 1944                                                    Laura           88
# 1945                                          Brief Encounter           86
# 1946                                                Notorious          102
# 1948                                                     Rope           80
# 1949                                            The Third Man          104
# 1950                                                   Harvey          104
# 1951                            The Day the Earth Stood Still           92
# 1952                                                High Noon           85
# 1953                                    From Here to Eternity          118
# 1954                                        Dial M for Murder          105
# 1955                                    Rebel Without a Cause          111
# 1956                           Invasion of the Body Snatchers           80
# 1957                                           Paths of Glory           88
# 1958                                            Touch of Evil           95
# 1959                                         Some Like It Hot          121
# 1960                                            Jungfrukällan           89
# 1961                                            The Innocents          100
# 1962                                                  Sanjuro           96
# 1963                                                  Charade          113
# 1964                                       A Hard Day's Night           87
# 1965                               Per qualche dollaro in più          132
# 1966                                                   Blowup          111
# 1967                                          The Jungle Book           78
# 1968                                           The Odd Couple          105
# 1969                       Butch Cassidy and the Sundance Kid          110
# 1970                                           Il conformista          113
# 1971                                         Harold and Maude           91
# 1972                                       Viskningar och rop           91
# 1973                                       La planète sauvage           72
# 1974                                          Blazing Saddles           93
# 1975                                           Love and Death           85
# 1976                                              Taxi Driver          114
# 1977                                               Annie Hall           93
# 1978                                                Halloween           91
# 1978                                           Watership Down           91
# 1979                                             The Warriors           92
# 1980                                                Airplane!           88
# 1981                                                Mad Max 2           96
# 1982                                              First Blood           93
# 1983                                                    Zelig           79
# 1984                                       This Is Spinal Tap           82
# 1985                                 The Purple Rose of Cairo           82
# 1986                                              Stand by Me           89
# 1987                                             Evil Dead II           84
# 1988           The Naked Gun: From the Files of Police Squad!           85
# 1989                                       The Little Mermaid           83
# 1990                                               Home Alone          103
# 1991                                     Beauty and the Beast           84
# 1992                               The Muppet Christmas Carol           85
# 1993                           The Nightmare Before Christmas           76
# 1993                             Batman: Mask of the Phantasm           76
# 1994                                            The Lion King           88
# 1995                                                Toy Story           81
# 1996                                            Trainspotting           93
# 1997                                            Pâfekuto burû           81
# 1998                                         Le dîner de cons           80
# 1999                       South Park: Bigger, Longer & Uncut           81
# 2000                                         Fa yeung nin wah           98
# 2001                                                    Shrek           90
# 2002                                             Mou gaan dou          101
# 2003                             Les triplettes de Belleville           80
# 2004                                            Before Sunset           80
# 2005                                              Adams æbler           94
# 2006                                                 Papurika           90
# 2007                                                     Once           86
# 2008                                                    Taken           90
# 2009                                        Fantastic Mr. Fox           87
# 2010                                                  Flipped           90
# 2011                                        Midnight in Paris           96
# 2012                                         Moonrise Kingdom           94
# 2013                                                  Gravity           91
# 2014                                What We Do in the Shadows           86
# 2015                                               Inside Out           95
# 2016                                          I, Daniel Blake          100
# 2017                                           Loving Vincent           94
# 2018                                             Isle of Dogs          101
# 2019                                                    Klaus           96
# 2020                                                     Soul          100

# %%
# Plotting lowest runtime over time

plt.plot(lw_rt_by_year['Released_Year'], lw_rt_by_year['Runtime_min'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Run Time (min)')
plt.title('Lowest Run Time Over Time')
plt.grid()
plt.show()

# %% [markdown]
# #### Lowest Gross
#
# For this part, I'll find movies with the lowest all time gross and movies with the lowest gross grouped by year.

# %%
# Movies with the lowest all time gross

at_low_gr = mv_rating_clean[mv_rating_clean['Gross_num'] == mv_rating_clean['Gross_num'].min()]
at_low_gr[['Released_Year', 'Series_Title', 'Gross_num']]
# Out:
#      Released_Year Series_Title  Gross_num
# 630           2005  Adams æbler       1305

# %%
# Movies with the lowest gross grouped by year

lw_gr_by_year = mv_rating_clean.groupby('Released_Year').min().reset_index()
lw_gr_by_year_ss = movie_finder(lw_gr_by_year['Released_Year'], lw_gr_by_year['Gross_num'], 'Released_Year', 'Gross_num')
print(lw_gr_by_year_ss[['Released_Year', 'Series_Title', 'Gross_num']].set_index('Released_Year').to_string())
# Out:
#                                                                        Series_Title  Gross_num
# Released_Year
# 1921                                                                        The Kid    5450000
# 1924                                                                   Sherlock Jr.     977375
# 1925                                                                  The Gold Rush    5450000
# 1926                                                                    The General    1033895
# 1927                                                  Sunrise: A Song of Two Humans     539540
# 1928                                                     La passion de Jeanne d'Arc      21877
# 1930                                                 All Quiet on the Western Front    3270000
# 1931                                                                    City Lights      19181
# 1932                                              Scarface: The Shame of the Nation   23530892
# 1933                                                                      King Kong   10000000
# 1934                                                          It Happened One Night    4360000
# 1935                                                           A Night at the Opera    2537520
# 1936                                                                   Modern Times     163245
# 1938                                                   The Adventures of Robin Hood    3981000
# 1939                                                               The Wizard of Oz    2076020
# 1940                                                            The Grapes of Wrath      55000
# 1941                                                                   Citizen Kane    1585634
# 1942                                                                     Casablanca    1024560
# 1943                                                              Shadow of a Doubt   23530892
# 1944                                                                          Laura    4360000
# 1945                                                               The Lost Weekend    9460000
# 1946                                                                  The Big Sleep    6540000
# 1948                                               The Treasure of the Sierra Madre    5014000
# 1949                                                                  The Third Man     449191
# 1950                                                                  All About Eve      10177
# 1951                                                              The African Queen     536118
# 1952                                                            Singin' in the Rain    8819028
# 1953                                                               Tôkyô monogatari   23530892
# 1953                                                          Le salaire de la peur   23530892
# 1954                                                              Dial M for Murder      12562
# 1955                                                                   East of Eden   23530892
# 1955                                                          Rebel Without a Cause   23530892
# 1956                                                                    The Killing   23530892
# 1956                                                                  The Searchers   23530892
# 1956                                                 Invasion of the Body Snatchers   23530892
# 1956                                                                          Giant   23530892
# 1957                                                                   12 Angry Men    4360000
# 1958                                                                  Touch of Evil    2237659
# 1959                                                                      Rio Bravo   12535000
# 1960                                                              À bout de souffle     336705
# 1961                                                                  The Innocents    2616000
# 1962                                               What Ever Happened to Baby Jane?    4050000
# 1963                                                                      The Birds   11403529
# 1964           Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb     275902
# 1965                                                     Per qualche dollaro in più   15000000
# 1966                                                                  Andrei Rublev     102021
# 1967                                                                  Belle de jour      26331
# 1968                                                   Once Upon a Time in the West    5321508
# 1969                                                                 The Wild Bunch   12064472
# 1970                                                                 Il conformista     541940
# 1971                                                                   Giù la testa     696690
# 1972                                            Le charme discret de la bourgeoisie     198809
# 1973                                                             La montaña sagrada      61001
# 1974                                                               The Conversation    4420000
# 1975                                                                        Zerkalo     177345
# 1976                                                                   Le locataire    1924733
# 1977                                                                     Annie Hall   39200000
# 1978                                                               Dawn of the Dead    5100000
# 1979                                                                        Stalker     234723
# 1980                                                                    Raging Bull   23383987
# 1981                                                                       Das Boot   11487676
# 1982                                                             The King of Comedy    2500000
# 1983                                                                          Zelig   11798616
# 1984                                                             This Is Spinal Tap     188751
# 1985                                                                            Ran    4135750
# 1986                                                                    Down by Law    1436000
# 1987                                                                   Withnail & I    1544889
# 1988                                                                 Dom za vesanje     280015
# 1989                                       My Left Foot: The Story of Christy Brown   14743391
# 1990                                                              Miller's Crossing    5080409
# 1991                                                              Omohide poro poro     453243
# 1992                                                                 Reservoir Dogs    2832029
# 1993                                                           Trois couleurs: Bleu    1324974
# 1994                                                             Chung Hing sam lam     600200
# 1995                                                                       La haine     309811
# 1996                                                             Breaking the Waves    4040691
# 1997                                                                  Abre los ojos     368234
# 1998                                           La leggenda del pianista sull'oceano     259127
# 1999                                                            The Boondock Saints      25812
# 2000                                                    Vampire Hunter D: Bloodlust     151086
# 2001                                              Lagaan: Once Upon a Time in India      70147
# 2002                                                            Boksuneun naui geot      45289
# 2003                                                                 Salinui chueok      14131
# 2004                                                                        Bin-jip     238507
# 2005                                                                    Adams æbler       1305
# 2006                                                               Efter brylluppet     412544
# 2007                                                                 Tropa de Elite       8060
# 2008                                                                      Okuribito    1498210
# 2009                                                                     Mr. Nobody       3600
# 2010                                                                        Ajeossi       6460
# 2011                                                                       Rockstar     985912
# 2012                                                               Paan Singh Tomar      39567
# 2013                                                            La migliore offerta      85433
# 2014                                                                 Omoide no Mânî     765127
# 2015                                                                         Talvar     342370
# 2016                                                                I, Daniel Blake     258168
# 2017                                                                       Nelyubov     566356
# 2018                                                                      Andhadhun    1373943
# 2019                                                                    Jojo Rabbit     349555
# 2020                                                                       Hamilton   23530892
# 2020                                                                Soorarai Pottru   23530892
# 2020                                                                           Soul   23530892
# 2020                                                                    Dil Bechara   23530892
# 2020                                                     The Trial of the Chicago 7   23530892

# %%
# Plotting lowest gross over time

plt.plot(lw_gr_by_year['Released_Year'], lw_gr_by_year['Gross_num'], marker='.')
plt.xlabel('Release Year')
plt.ylabel('Gross (USD)')
plt.title('Lowest Gross Over Time')
plt.grid()
plt.show()

# %% [markdown]
# #### Does the duration of movies in the 2000s last longer compared to the 1900s?

# %%
# Create 2 new dfs

mv_year_1900s = mv_rating_clean[mv_rating_clean['Released_Year'] < 2000]
mv_year_2000s = mv_rating_clean[~(mv_rating_clean['Released_Year'] < 2000)]

# %%
# Making sure that the filtering is correct

mv_year_1900s['Released_Year'].unique()
# Out:
# array([1994, 1972, 1974, 1957, 1993, 1999, 1966, 1990, 1980, 1975, 1998,
#        1997, 1995, 1991, 1977, 1954, 1946, 1988, 1985, 1968, 1960, 1942,
#        1936, 1931, 1984, 1981, 1979, 1971, 1964, 1950, 1940, 1992, 1987,
#        1986, 1983, 1976, 1973, 1965, 1962, 1959, 1958, 1952, 1944, 1941,
#        1921, 1989, 1978, 1963, 1961, 1953, 1948, 1925, 1924, 1996, 1982,
#        1967, 1951, 1949, 1939, 1934, 1928, 1927, 1926, 1970, 1969, 1956,
#        1945, 1930, 1955, 1938, 1935, 1933, 1943, 1932])

# %%
mv_year_2000s['Released_Year'].unique()
# Out:
# array([2008, 2003, 2010, 2001, 2002, 2020, 2019, 2014, 2011, 2006, 2000,
#        2018, 2017, 2016, 2012, 2009, 2007, 2013, 2004, 2015, 2005])

# %% [markdown]
# Plotting a boxplot to see the distribution of both dfs to decide if taking the mean for comparing the run time is possible, if there are a lot of outliers, I'll take the median value to compare both of them.

# %%
plt.boxplot(mv_year_1900s['Runtime_min'])
plt.ylabel('Run Time (min)')
plt.title('Run Time Distribution in the 1900s')
plt.grid()
plt.show()

# %%
plt.boxplot(mv_year_2000s['Runtime_min'])
plt.ylabel('Run Time (min)')
plt.title('Run Time Distribution in the 2000s')
plt.grid()
plt.show()

# %% [markdown]
# Looks like the 1900s run time distribution contains a lot of outliers. Therefore, I'll take the median values to compare their run time.

# %%
rt_median_1900s = mv_year_1900s['Runtime_min'].median()
rt_median_2000s = mv_year_2000s['Runtime_min'].median()

print(f'1900s Movie Run Time Median: {rt_median_1900s} minutes\n2000s Movie Run Time Median: {rt_median_2000s} minutes')
# Out:
# 1900s Movie Run Time Median: 116.0 minutes
# 2000s Movie Run Time Median: 123.0 minutes

# %% [markdown]
# As seen from the results, the run time in the 1900s and the 2000s didn't differ by much however, movies in the 2000s tend to last longer than movies in the 1900s.

# %% [markdown]
# #### Does movies in the 1900s tend to have a higher rating than the 2000s?

# %%
plt.boxplot(mv_year_1900s['IMDB_Rating'])
plt.ylabel('IMDB Rating')
plt.title('Run Time Distribution in the 1900s')
plt.grid()
plt.show()

# %%
plt.boxplot(mv_year_2000s['IMDB_Rating'])
plt.ylabel('IMDB Rating')
plt.title('Run Time Distribution in the 1900s')
plt.grid()
plt.show()

# %%
rat_median_1900s = mv_year_1900s['IMDB_Rating'].median()
rat_median_2000s = mv_year_2000s['IMDB_Rating'].median()

print(f'1900s Movie IMDB Rating Median: {rat_median_1900s}\n2000s Movie IMDB Rating Median: {rat_median_2000s}')
# Out:
# 1900s Movie IMDB Rating Median: 8.0
# 2000s Movie IMDB Rating Median: 7.9

# %% [markdown]
# From the results shown, I would say that as time goes by, movie ratings are approximately the same. To be more specific, from the 1900s to the 2000s, the median movie ratings only dropped by 0.1 which is not that big of a deal and can be implied that on average, the passing of time doesn't affect the movie ratings.

# %% [markdown]
# #### Count of certificate category (ex: A 4, UA 8, etc)

# %%
cert_count = mv_rating_clean['Certificate_new'].value_counts()
cert_count
# Out:
# U           246
# A           198
# UA          176
# R           146
# PG-13        43
# PG           42
# Passed       34
# Approved     11
# TV-14         1
# 16            1
# Unrated       1
# Name: Certificate_new, dtype: int64

# %%
cert_count.plot(kind='bar', x=cert_count.index)
plt.xlabel('Certification Categories')
plt.ylabel('Count')
plt.title('Counts of Certification Categories')
plt.grid()
plt.show()

# %% [markdown]
# Looks like overall, most of the movies are rated U which means that it could be watched by people of all ages followed by A rating which means that the target audience are adults. After that it's followed by UA, R and so on.

# %% [markdown]
# #### Does a high gross movie mean a higher rating for a given movie?

# %%
# Scatter plot for imdb rating vs gross

sns.stripplot(x='IMDB_Rating', y='Gross_num', data=mv_rating_clean, jitter=True, alpha=0.1, color='b')
plt.xlabel('IMDB Rating')
plt.ylabel('Gross (USD)')
plt.title('IMDB Rating vs Gross')
plt.show()

# %%
rat_gr_df = pd.DataFrame(columns=['IMDB_Rating', 'Gross_num'])
rat_gr_df['IMDB_Rating'] = mv_rating_clean['IMDB_Rating']
rat_gr_df['Gross_num'] = mv_rating_clean['Gross_num']

rat_gr_df.corr()
# Out:
#              IMDB_Rating  Gross_num
# IMDB_Rating     1.000000   0.086132
# Gross_num       0.086132   1.000000

# %% [markdown]
# From the scatter plot, the data points are not even linearly correlated at all and most of the data points are clustered near the 0 tick of the y-axis. When looking at the correlation coefficient, the value is close to 0 which means that they are not correlated at all.

# %% [markdown]
# #### Does a high no. of votes mean that a movie will have a higher gross?

# %%
nv_gr_df = pd.DataFrame(columns=['No_of_Votes', 'Gross_num'])
nv_gr_df['No_of_Votes'] = mv_rating_clean['No_of_Votes']
nv_gr_df['Gross_num'] = mv_rating_clean['Gross_num']

nv_gr_df.corr()
# Out:
#              No_of_Votes  Gross_num
# No_of_Votes     1.000000   0.576514
# Gross_num       0.576514   1.000000

# %%
plt.scatter(nv_gr_df['No_of_Votes'], nv_gr_df['Gross_num'], alpha=0.05)
plt.xlabel('No. of Votes')
plt.ylabel('Gross (USD)')
plt.title('No. of Votes vs Gross')
plt.show()

# %%
plt.scatter(nv_gr_df['No_of_Votes'], nv_gr_df['Gross_num'], alpha=0.1)
plt.xlabel('No. of Votes')
plt.ylabel('Gross (USD)')
plt.title('No. of Votes vs Gross')
plt.xlim([0, 0.5e6])
plt.ylim([0, 1e8])
plt.show()

# %% [markdown]
# When looking at the correlation coefficient only, it's seen that number of votes and the gross of a movie are moderately correlated in some way. When we see the scatter plot, it looks like the higher the number of votes a movie has, the larger its gross value. However, overplotting can be observed at the bottom left of the plot. After zooming in to that particular area, the data points seem to be randomly spread out and as seen on the result below, the correlation coefficient becomes smaller.

# %%
nv_gr_df_filtered = nv_gr_df[(nv_gr_df['No_of_Votes'] <= 5e5) & (nv_gr_df['Gross_num'] <= 1e8)]

nv_gr_df_filtered.corr()
# Out:
#              No_of_Votes  Gross_num
# No_of_Votes     1.000000   0.408333
# Gross_num       0.408333   1.000000
